# %%
import pandas as pd 

pd.set_option('display.max_columns', None)

# %%
df_part7 = pd.read_csv('../data/데이터셋/dataset1_general.csv', encoding='CP949')
df_part7
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        경기민감도      총자본증가율       순이익증가율    자기자본증가율     매출액증가율  종업원수증가율  \
# 0          1   13.166482    80.280163   5.219839  56.396905     4.65
# 1          1  109.147119  -341.571868  75.170505  -8.429134    -0.74
# 2          1   -2.093352  2348.675303  55.100407  25.510008     1.49
# 3          1    3.855597   -46.641074   0.010946  11.520576    20.59
# 4          1   -2.644307 -2409.614083  -4.480893  18.851969    -4.88
# ...      ...         ...          ...        ...        ...      ...
# 12738      0    7.026008    17.748954  24.611435   5.977506    -3.78
# 12739      0   13.690307     1.063296   7.760601   7.171915     9.90
# 12740      0   21.933460   -42.676587   3.389326   2.420227     7.68
# 12741      0   21.081715  -263.287062  11.215038  -1.581947    15.87
# 12742      0  -11.431409  -327.993526 -39.276758   0.562842    -2.23
#
#          정상영업손익증가율  매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  \
# 0      1263.950784        3.61    -8.50    -5.58        2.37         3.51
# 1      -756.819406      -25.87   -40.97   -15.78       -9.96       -16.95
# 2       631.501169        3.88     1.45     0.52        1.40         1.96
# 3       -44.098325        1.94     0.69     0.28        0.78         0.90
# 4      -681.514824       -9.51   -13.50    -6.37       -4.49        -5.37
# ...            ...         ...      ...      ...         ...          ...
# 12738   -41.383093        2.51     2.36     3.29        3.50        13.80
# 12739    -3.906495        2.25     2.22     3.01        3.04        11.51
# 12740    14.408829        2.51     1.24     1.46        2.95        12.48
# 12741   -72.247242        0.71    -2.06    -1.96        0.67         3.23
# 12742  -322.165979       -1.57    -8.79    -8.13       -1.45        -8.47
#
#        자기자본순이익률  금융비용부담률    수지비율  사내유보 대 자기자본비율       1주당매출액      1주당순이익  \
# 0         -8.28     0.80  108.35        -245.87   406.280703  -34.519834
# 1        -26.84     2.53  140.55        -165.71   246.198501 -100.872314
# 2          0.74     1.65   98.55        -106.33   235.517466    3.419043
# 3          0.32    -0.65   99.32        -106.65   262.650435    1.824365
# 4      9.092000e+01  15.96   134.474407       27.671795  114.243590
# ...             ...    ...          ...             ...         ...
# 12738  5.737466e+06  10.48    37.002209      103.399418  318.938865
# 12739  1.218393e+07  10.93    48.001879      102.744066  423.879470
# 12740  3.459744e+09  12.28    50.647901      108.702706  590.180812
# 12741  3.509713e+09  12.66    66.490562       86.464501  709.037155
# 12742  1.535742e+09   5.51   131.187104       44.778480  605.404995
#
#         기계장비율_계산     자본집약도_계산  총자본회전률   자기자본회전률  타인자본회전률  유동자산회전률  당좌자산회전률  \
# 0      19.715837   204.066667    0.66  0.984333     2.01     1.25     1.55
# 1      18.562172   425.291045    0.39  0.655130     0.93     0.52     0.57
# 2      17.604882   411.485294    0.36  0.506332     1.26     0.48     0.52
# 3      30.445768   354.432927    0.40  0.464339     2.85     0.68     0.80
# 4      28.007199   362.769231    0.47  0.564493     2.88     0.99     1.22
# ...          ...          ...     ...       ...      ...      ...      ...
# 12738   0.000000   795.036390    1.39  6.107006     1.87     5.18     5.70
# 12739   0.000000   831.529801    1.35  5.499239     1.84     4.98     5.44
# 12740   0.000000   948.600246    1.17  5.113218     1.54     5.83     6.38
# 12741   0.000000  1000.623142    0.95  4.964267     1.20     6.98     7.96
# 12742   0.000000   905.653637    0.93  4.550483     1.12     7.68     9.30
#
#        재고자산회전률  매출채권회전률  순운전자본회전률
# 0         6.42     2.45      0.86
# 1         5.71     1.85      0.42
# 2         5.39     2.07      0.42
# 3         4.77     1.86      0.56
# 4         5.22     2.10      0.75
# ...        ...      ...       ...
# 12738    56.65    27.46      2.02
# 12739    59.77    26.03      2.03
# 12740    68.48    25.33      2.15
# 12741    56.47    25.24      2.19
# 12742    44.09    23.08      2.09
#
# [12743 rows x 59 columns]

# %% [markdown]
# ### inf, -inf 값 확인

# %%
import numpy as np
df_part7[(df_part7 == np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7[(df_part7 == -np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7.isna().sum()
# Out:
# 회사명                      0
# 거래소코드                    0
# 회계년도                     0
# 상장일                      0
# 상장폐지일_x              12288
# 부실기업1                    0
# 부실기업2                    0
# 부실기업                     0
# 업종                       0
# 경기민감도                    0
# 총자본증가율                   0
# 순이익증가율                   0
# 자기자본증가율                  0
# 매출액증가율                   0
# 종업원수증가율                  0
# 정상영업손익증가율                0
# 매출액정상영업이익률               0
# 매출액순이익률                  0
# 총자본순이익률                  0
# 총자본정상영업이익률               0
# 자기자본정상영업이익률              0
# 자기자본순이익률                 0
# 금융비용부담률                  0
# 수지비율                     0
# 사내유보 대 자기자본비율            0
# 1주당매출액                   0
# 1주당순이익                   0
# 1주당 CASH FLOW            0
# 1주당순자산                   0
# 유보율                      0
# 자기자본구성비율                 0
# 유동비율                     0
# 당좌비율                     0
# 현금비율                     0
# 매출채권 대 매입채무비율            0
# 부채비율                     0
# 이자보상배율                   0
# CASH FLOW 대 부채비율         0
# CASH FLOW 대 차입금비율        0
# CASH FLOW 대 총자본비율        0
# CASH FLOW 대 매출액비율        0
# 재고자산대순운전자본비율             0
# 총자본투자효율                  0
# 설비투자효율                   0
# 기계투자효율                   0
# 부가가치율                    0
# 노동소득분배율                  0
# 종업원1인당부가가치율_계산           0
# 노동장비율_계산                 0
# 기계장비율_계산                 0
# 자본집약도_계산                 0
# 총자본회전률                   0
# 자기자본회전률                  0
# 타인자본회전률                  0
# 유동자산회전률                  0
# 당좌자산회전률                  0
# 재고자산회전률                  0
# 매출채권회전률                  0
# 순운전자본회전률                 0
# dtype: int64

# %% [markdown]
# ## 윈저라이징

# %%
wins_df_part7 = df_part7.copy()

# %%
# 윈저라이징 할 컬럼 데이터프레임
wins_df_part7 = wins_df_part7.iloc[:, 10:]

# %%
from scipy.stats.mstats import winsorize

# 윈저라이징 함수 생성
def winsorize_col(winsordf, col):
    winsordf[col] = winsorize(winsordf[col], limits=[0.025, 0.025])

# %%
# 윈저라이징 적용
for i in wins_df_part7.columns:
    winsorize_col(wins_df_part7, i)

# %%
wins_df = pd.DataFrame()
wins_df = df_part7.iloc[:, :10]
wins_df[wins_df_part7.columns.tolist()] = wins_df_part7[wins_df_part7.columns.tolist()]
wins_df
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        경기민감도     총자본증가율      순이익증가율    자기자본증가율     매출액증가율  종업원수증가율  \
# 0          1  13.166482   80.280163   5.219839  56.396905     4.65
# 1          1  78.275781 -341.571868  75.170505  -8.429134    -0.74
# 2          1  -2.093352  794.754625  55.100407  25.510008     1.49
# 3          1   3.855597  -46.641074   0.010946  11.520576    20.59
# 4          1  -2.644307 -981.272492  -4.480893  18.851969    -4.88
# ...      ...        ...         ...        ...        ...      ...
# 12738      0   7.026008   17.748954  24.611435   5.977506    -3.78
# 12739      0  13.690307    1.063296   7.760601   7.171915     9.90
# 12740      0  21.933460  -42.676587   3.389326   2.420227     7.68
# 12741      0  21.081715 -263.287062  11.215038  -1.581947    15.87
# 12742      0 -11.431409 -327.993526 -31.512717   0.562842    -2.23
#
#         정상영업손익증가율  매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  \
# 0      594.671706        3.61    -8.50    -5.58        2.37         3.51
# 1     -432.398636      -20.38   -33.87   -15.78       -9.96       -16.95
# 2      594.671706        3.88     1.45     0.52        1.40         1.96
# 3      -44.098325        1.94     0.69     0.28        0.78         0.90
# 4     -432.398636       -9.51   -13.50    -6.37       -4.49        -5.37
# ...           ...         ...      ...      ...         ...          ...
# 12738  -41.383093        2.51     2.36     3.29        3.50        13.80
# 12739   -3.906495        2.25     2.22     3.01        3.04        11.51
# 12740   14.408829        2.51     1.24     1.46        2.95        12.48
# 12741  -72.247242        0.71    -2.06    -1.96        0.67         3.23
# 12742 -322.165979       -1.57    -8.79    -8.13       -1.45        -8.47
#
#        자기자본순이익률  금융비용부담률    수지비율  사내유보 대 자기자본비율       1주당매출액      1주당순이익  \
# 0         -8.28     0.80  108.35         -92.25   694.745234  -34.519834
# 1        -26.84     2.53  128.63         -92.25   694.745234 -100.872314
# 2          0.74     1.65   98.55         -92.25   694.745234    3.419043
# 3          0.32    -0.65   99.32         -92.25   694.745234    1.824365
# 4         -7.62    -0.11  113.24         -92.25   694.745234  -41.338674
# ...         ...      ...     ...            ...          ...         ...
# 12738     12.97     1.84   95.90          18.35  9088.600308  214.300424
# 2               0.125782           0.003549      0.483544  0.297707  0.050361
# 3               0.205223           0.156176      0.495145  0.291235  0.029227
# 4               0.408974           0.460483      0.501729  0.207470  0.022066
# ...                  ...                ...           ...       ...       ...
# 12738           0.480324           0.406058      0.446848  0.327663  0.028610
# 12739           0.384332           0.362518      0.451538  0.323225  0.024000
# 12740           0.386907           0.371273      0.458982  0.308802  0.020633
# 12741           0.369621           0.369617      0.456477  0.269416  0.017640
# 12742           0.289077           0.311406      0.458444  0.166790  0.013710
#
#          기계투자효율     부가가치율   노동소득분배율  종업원1인당부가가치율_계산  노동장비율_계산  기계장비율_계산  \
# 0      0.002080  0.358736  0.632100        0.135085  0.059266  0.060233
# 1      0.000794  0.106125  1.000000        0.098507  0.057221  0.056708
# 2      0.003835  0.566610  0.548022        0.166541  0.066127  0.053784
# 3      0.002118  0.520745  0.573087        0.155978  0.096687  0.093014
# 4      0.001669  0.307931  0.834669        0.135731  0.096171  0.085564
# ...         ...       ...       ...             ...       ...       ...
# 12738  1.000000  0.230596  0.392508        0.235240  0.272919  0.000000
# 12739  1.000000  0.236946  0.442406        0.234379  0.363531  0.000000
# 12740  1.000000  0.255998  0.454409        0.242209  0.507127  0.000000
# 12741  1.000000  0.261360  0.526276        0.212987  0.609756  0.000000
# 12742  1.000000  0.160457  0.819757        0.158210  0.520273  0.000000
#
#        자본집약도_계산    총자본회전률   자기자본회전률   타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률  \
# 0      0.002303  0.197044  0.102584  0.188406  0.166667  0.142241  0.009971
# 1      0.019570  0.064039  0.049509  0.046113  0.002252  0.001437  0.008868
# 2      0.018492  0.049261  0.025520  0.089592  0.000000  0.000000  0.008371
# 3      0.014039  0.068966  0.018750  0.299078  0.038288  0.034483  0.007408
# 4      0.014690  0.103448  0.034897  0.303030  0.108108  0.094828  0.008107
# ...         ...       ...       ...       ...       ...       ...       ...
# 12738  0.048429  0.556650  0.928464  0.169960  1.000000  0.738506  0.087984
# 12739  0.051277  0.536946  0.830480  0.166008  1.000000  0.701149  0.092829
# 12740  0.060415  0.448276  0.768245  0.126482  1.000000  0.836207  0.106357
# 12741  0.064475  0.339901  0.744231  0.081686  1.000000  1.000000  0.087704
# 12742  0.057063  0.330049  0.677521  0.071146  1.000000  1.000000  0.068477
#
#         매출채권회전률  순운전자본회전률
# 0      0.017325  0.237443
# 1      0.000000  0.036530
# 2      0.005775  0.036530
# 3      0.000000  0.100457
# 4      0.006687  0.187215
# ...         ...       ...
# 12738  0.777508  0.767123
# 12739  0.734043  0.771689
# 12740  0.712766  0.826484
# 12741  0.710030  0.844749
# 12742  0.644377  0.799087
#
# [12743 rows x 49 columns]

# %% [markdown]
# ### MinMaxScaler 히스토그램

# %%
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(scaled_df_part7, axs.T.ravel()):
    sns.distplot(scaled_df_part7[col], ax=ax)

plt.show()

# %% [markdown]
# ### MinMaxScaler 박스플롯

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(scaled_df_part7, axs.T.ravel()):
    scaled_df_part7[[col]].boxplot(ax=ax)

plt.show()

# %% [markdown]
# ### MinMaxScaler Q-Q Plot

# %%
from scipy import stats

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 10

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for ax, i in zip(axs.ravel(), scaled_df_part7):
       stats.probplot(scaled_df_part7[i], dist=stats.norm, plot=ax)
       ax.set_title(str(i))

plt.show()

# %% [markdown]
# ### MinMaxScaler K-S Test

# %%
import numpy as np
from scipy.stats import kstest

def ks_test(df_name):
    ks_columns = []
    ks_columns.append([col for col in df_name])
    for i in ks_columns:
        for j in i:
            ks_test = kstest(df_name[j], 'norm')
            print(j, "의 pvalue:", ks_test.pvalue)

# %%
ks_test(scaled_df_part7)
# Out:
# 총자본증가율 의 pvalue: 0.0
# 순이익증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액증가율 의 pvalue: 0.0
# 종업원수증가율 의 pvalue: 0.0
# 정상영업손익증가율 의 pvalue: 0.0
# 매출액정상영업이익률 의 pvalue: 0.0
# 매출액순이익률 의 pvalue: 0.0
# 총자본순이익률 의 pvalue: 0.0
# 총자본정상영업이익률 의 pvalue: 0.0
# 자기자본정상영업이익률 의 pvalue: 0.0
# 자기자본순이익률 의 pvalue: 0.0
# 금융비용부담률 의 pvalue: 0.0
# 수지비율 의 pvalue: 0.0
# 사내유보 대 자기자본비율 의 pvalue: 0.0
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 0.0
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 0.0
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 0.0
# CASH FLOW 대 매출액비율 의 pvalue: 0.0
# 재고자산대순운전자본비율 의 pvalue: 0.0
# 총자본투자효율 의 pvalue: 0.0
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# 부가가치율 의 pvalue: 0.0
# 노동소득분배율 의 pvalue: 0.0
# 종업원1인당부가가치율_계산 의 pvalue: 0.0
# 노동장비율_계산 의 pvalue: 0.0
# 기계장비율_계산 의 pvalue: 0.0
# 자본집약도_계산 의 pvalue: 0.0
# 총자본회전률 의 pvalue: 0.0
# 자기자본회전률 의 pvalue: 0.0
# 타인자본회전률 의 pvalue: 0.0
# 유동자산회전률 의 pvalue: 0.0
# 당좌자산회전률 의 pvalue: 0.0
# 재고자산회전률 의 pvalue: 0.0
# 매출채권회전률 의 pvalue: 0.0
# 순운전자본회전률 의 pvalue: 0.0

# %% [markdown]
# ### MinMaxScaler Shapiro–Wilk test

# %%
# pvalue 함수

from scipy import stats
from scipy.stats import shapiro

# 등락률 컬럼만 추출해서 pvalue 구하는 함수
def shap_pct(df_name):
    pct_columns = []
    pct_columns.append([col for col in df_name])
    for i in pct_columns:
        for j in i:
            shapiro_test = shapiro(df_name[j])
            print(j, "의 pvalue:", shapiro_test.pvalue)

# %%
# 컬럼별 pvalue 값 출력
shap_pct(scaled_df_part7)
# Out:
# 총자본증가율 의 pvalue: 0.0
# 순이익증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액증가율 의 pvalue: 0.0
# 종업원수증가율 의 pvalue: 0.0
# 정상영업손익증가율 의 pvalue: 0.0
# 매출액정상영업이익률 의 pvalue: 0.0
# 매출액순이익률 의 pvalue: 0.0
# 총자본순이익률 의 pvalue: 0.0
# 총자본정상영업이익률 의 pvalue: 4.203895392974451e-45
# 자기자본정상영업이익률 의 pvalue: 0.0
# 자기자본순이익률 의 pvalue: 0.0
# 금융비용부담률 의 pvalue: 0.0
# 수지비율 의 pvalue: 0.0
# 사내유보 대 자기자본비율 의 pvalue: 0.0
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 1.401298464324817e-44
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 0.0
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 1.3179700025543808e-30
# CASH FLOW 대 매출액비율 의 pvalue: 1.2751816025355835e-43
# 재고자산대순운전자본비율 의 pvalue: 0.0
# 총자본투자효율 의 pvalue: 1.2387478424631383e-42
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# 부가가치율 의 pvalue: 0.0
# 노동소득분배율 의 pvalue: 0.0
# 종업원1인당부가가치율_계산 의 pvalue: 0.0
# 노동장비율_계산 의 pvalue: 0.0
# 기계장비율_계산 의 pvalue: 0.0
# 자본집약도_계산 의 pvalue: 0.0
# 총자본회전률 의 pvalue: 0.0
# 자기자본회전률 의 pvalue: 0.0
# 타인자본회전률 의 pvalue: 0.0
# 유동자산회전률 의 pvalue: 0.0
# 당좌자산회전률 의 pvalue: 0.0
# 재고자산회전률 의 pvalue: 0.0
# 매출채권회전률 의 pvalue: 0.0
# 순운전자본회전률 의 pvalue: 0.0

# %% [markdown]
# ## Logit T 검정

# %%
mm_df = pd.DataFrame()
mm_df = df_part7.iloc[:, :10]
mm_df[scaled_df_part7.columns.tolist()] = scaled_df_part7[scaled_df_part7.columns.tolist()]
mm_df
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        경기민감도    총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  \
# 0          1  0.053236  0.058813  0.024943  0.006134  0.029168   0.855967
# 1          1  0.099951  0.058740  0.026355  0.003587  0.027662   0.846826
# 2          1  0.045808  0.059206  0.025950  0.004921  0.028285   0.853106
# 3          1  0.048704  0.058791  0.024837  0.004371  0.033624   0.850050
# 4          1  0.045540  0.058382  0.024747  0.004659  0.026505   0.847166
# ...      ...       ...       ...       ...       ...       ...        ...
# 12738      0  0.050247  0.058802  0.025334  0.004153  0.026812   0.850062
# 12739      0  0.053491  0.058799  0.024994  0.004200  0.030636   0.850232
# 12740      0  0.057503  0.058792  0.024906  0.004013  0.030015   0.850315
# 12741      0  0.057088  0.058754  0.025064  0.003856  0.032304   0.849923
# 12742      0  0.041263  0.058742  0.024044  0.003940  0.027245   0.848792
#
#        매출액정상영업이익률   매출액순이익률   총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  자기자본순이익률  \
# 0        0.983937  0.352680  0.328319    0.447793     0.624747  0.662897
# 1        0.977904  0.350160  0.301723    0.381327     0.588105  0.657684
# 2        0.983992  0.353453  0.344223    0.442564     0.621971  0.665430
# 3        0.983595  0.353394  0.343598    0.439222     0.620073  0.665312
# 4        0.981252  0.352292  0.326259    0.410813     0.608844  0.663082
# ...           ...       ...       ...         ...          ...       ...
# 12738    0.983712  0.353523  0.351446    0.453884     0.643176  0.668865
# 12739    0.983658  0.353512  0.350716    0.451404     0.639074  0.668415
# 12740    0.983712  0.353436  0.346674    0.450919     0.640812  0.666958
# 12741    0.983343  0.353180  0.337757    0.438629     0.624246  0.662582
# 12742    0.982877  0.352658  0.321670    0.427201     0.603292  0.651876
#
#         금융비용부담률      수지비율  사내유보 대 자기자본비율    1주당매출액    1주당순이익  1주당 CASH FLOW  \
# 0      0.637319  0.111251       0.986000  0.000110  0.195952       0.123913
# 0      0.165608  0.462789  0.248316        0.362744  0.004559  0.008533
# 1      0.165608  0.459242  0.254883        0.362352  0.004408  0.008034
# 2      0.165608  0.465707  0.248242        0.363081  0.005066  0.007619
# 3      0.165608  0.465063  0.248264        0.362968  0.007323  0.013177
# 4      0.165608  0.462075  0.248492        0.362751  0.007285  0.012122
# ...         ...       ...       ...             ...       ...       ...
# 12738  0.165965  0.460989  0.248107        0.363817  0.020337  0.000000
# 12739  0.166367  0.461079  0.248150        0.363808  0.027028  0.000000
# 12740  0.381176  0.461346  0.248161        0.363892  0.037632  0.000000
# 12741  0.384289  0.461421  0.248223        0.363579  0.045211  0.000000
# 12742  0.261296  0.460005  0.248479        0.362992  0.038603  0.000000
#
#        자본집약도_계산    총자본회전률   자기자본회전률   타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률  \
# 0      0.000586  0.077556  0.289091  0.048757  0.069820  0.058201  0.000008
# 1      0.001255  0.045828  0.288665  0.022428  0.028716  0.021164  0.000007
# 2      0.001213  0.042303  0.288472  0.030473  0.026464  0.019274  0.000007
# 3      0.001041  0.047004  0.288417  0.069235  0.037725  0.029856  0.000006
# 4      0.001066  0.055229  0.288547  0.069966  0.055180  0.045729  0.000006
# ...         ...       ...       ...       ...       ...       ...       ...
# 12738  0.002373  0.163337  0.295730  0.045344  0.291104  0.215042  0.000069
# 12739  0.002483  0.158637  0.294942  0.044612  0.279842  0.205215  0.000073
# 12740  0.002837  0.137485  0.294442  0.037299  0.327703  0.240741  0.000083
# 12741  0.002994  0.111633  0.294249  0.029010  0.392455  0.300454  0.000069
# 12742  0.002707  0.109283  0.293713  0.027060  0.431869  0.351096  0.000054
#
#         매출채권회전률  순운전자본회전률
# 0      0.000011  0.073504
# 1      0.000008  0.035897
# 2      0.000009  0.035897
# 3      0.000008  0.047863
# 4      0.000009  0.064103
# ...         ...       ...
# 12738  0.000119  0.172650
# 12739  0.000113  0.173504
# 12740  0.000110  0.183761
# 12741  0.000110  0.187179
# 12742  0.000100  0.178632
#
# [12743 rows x 59 columns]

# %%
# 로짓모듈가져와서 진행 
import statsmodels.api as sm

# 피처값만 데이터프레임에 불러오기
df_mm_sig_copy = mm_df.copy() 
x = df_mm_sig_copy.iloc[:, 10:]

#  상수항 추가
x = sm.add_constant(x, has_constant = "add")
log_reg = sm.Logit(df_mm_sig_copy['부실기업'], x).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.171537
#          Iterations 13
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   부실기업   No. Observations:                12743
# Model:                          Logit   Df Residuals:                    12693
# Method:                           MLE   Df Model:                           49
# Date:                Mon, 03 Oct 2022   Pseudo R-squ.:                  0.2387
# Time:                        15:16:53   Log-Likelihood:                -2185.9
# converged:                       True   LL-Null:                       -2871.4
# Covariance Type:            nonrobust   LLR p-value:                7.470e-255
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# 타인자본회전률               1.3389      1.848      0.724      0.469      -2.284       4.961
# 유동자산회전률               3.9048      2.020      1.933      0.053      -0.054       7.864
# 당좌자산회전률               2.0747      1.435      1.446      0.148      -0.738       4.888
# 재고자산회전률               3.7823      1.914      1.976      0.048       0.031       7.534
# 매출채권회전률             -11.0965     50.968     -0.218      0.828    -110.992      88.799
# 순운전자본회전률            -14.3608      3.172     -4.528      0.000     -20.577      -8.144
# =====================================================================================

# %%
#로짓분석상 유의한 변수만을 추출
p_value = pd.DataFrame(log_reg.pvalues)
print(p_value[p_value[0] < 0.05], '\n유의한 변수의 수 :' ,len(p_value[p_value[0] < 0.05]))
# Out:
#                               0
# 총자본증가율             1.814851e-02
# 종업원수증가율            1.695372e-03
# 정상영업손익증가율          2.098865e-02
# 총자본정상영업이익률         1.083050e-15
# 금융비용부담률            1.403563e-03
# 수지비율               8.470853e-03
# 사내유보 대 자기자본비율      1.581345e-02
# 유보율                1.578644e-02
# 자기자본구성비율           5.697956e-03
# 유동비율               1.245117e-03
# 당좌비율               2.025880e-03
# 이자보상배율             2.808414e-02
# CASH FLOW 대 총자본비율  7.804569e-05
# 재고자산회전률            4.813859e-02
# 순운전자본회전률           5.963492e-06
# 유의한 변수의 수 : 15

# %%
# 4-1) VIF

import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def feature_engineering_XbyVIF(df_cols):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(df_cols.values, i)
                        for i in range(df_cols.shape[1])]
    vif['Feature'] = df_cols.columns
    return vif

# %%
# 4-2) VIf 데이터프레임 확인
feature_vif = feature_engineering_XbyVIF(mm_df.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#       VIF_Factor            Feature
# 0   36740.557811         매출액정상영업이익률
# 1   28021.173733  CASH FLOW 대 매출액비율
# 2   25202.957310      사내유보 대 자기자본비율
# 3   15887.031475              부가가치율
# 4   10315.077311             설비투자효율
# 5    7573.892884           자기자본구성비율
# 6    7525.132658   CASH FLOW 대 부채비율
# 7    6779.402635           자기자본순이익률
# 8    5009.235257          정상영업손익증가율
# 9    4570.740382            매출액순이익률
# 10   4084.044038            금융비용부담률
# 11   3679.065939            자기자본회전률
# 12   2195.328428     종업원1인당부가가치율_계산
# 13   2144.924861        자기자본정상영업이익률
# 14   1429.404939       재고자산대순운전자본비율
# 15   1147.647857            노동소득분배율
# 16    912.182945            총자본투자효율
# 17    856.722235         총자본정상영업이익률
# 18    820.148792            총자본순이익률
# 19    378.765670  CASH FLOW 대 총자본비율
# 20    315.323111             이자보상배율
# 21    217.628785             1주당순이익
# 22    208.761772               수지비율
# 23    197.058674      1주당 CASH FLOW
# 24    153.087648             기계투자효율
# 25    129.701265               유동비율
# 26    120.315492               당좌비율
# 27     54.150626           순운전자본회전률
# 28     50.204374             순이익증가율
# 29     46.981624            유동자산회전률
# 30     18.175301            당좌자산회전률
# 31     16.785294             총자본회전률
# 32     11.405588            타인자본회전률
# 33     11.306383             총자본증가율
# 34      9.304281            자기자본증가율
# 35      6.888660             1주당순자산
# 36      6.466554               현금비율
# 37      5.668421            종업원수증가율
# 38      5.179419             1주당매출액
# 39      4.044898               부채비율
# 40      2.755513                유보율
# 41      2.051279           노동장비율_계산
# 42      1.939627  CASH FLOW 대 차입금비율
# 43      1.914416           자본집약도_계산
# 44      1.683253           기계장비율_계산
# 45      1.570929             매출액증가율
# 46      1.018663      매출채권 대 매입채무비율
# 47      1.005133            재고자산회전률
# 48      1.003836            매출채권회전률

# %%
wins_vif = mm_df.drop(['매출액정상영업이익률',
'CASH FLOW 대 매출액비율',
'부가가치율',
'설비투자효율',
'CASH FLOW 대 부채비율',
'자기자본순이익률',
'매출액순이익률',
'자기자본회전률',
'종업원1인당부가가치율_계산',
'자기자본정상영업이익률',
'재고자산대순운전자본비율',
'노동소득분배율',
'총자본투자효율',
'1주당순이익',
'1주당 CASH FLOW',
'기계투자효율',
'순이익증가율',
'유동자산회전률',
'당좌자산회전률',
'총자본회전률',
'타인자본회전률',
'총자본순이익률'
],axis=1)

# %%
# 4-2) VIf 데이터프레임 재확인
feature_vif = feature_engineering_XbyVIF(wins_vif.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#      VIF_Factor            Feature
# 0   7946.763568      사내유보 대 자기자본비율
# 1   4478.803009          정상영업손익증가율
# 2   3959.786737           자기자본구성비율
# 3   2165.174994            금융비용부담률
# 4    313.629359             이자보상배율
# 5    253.174546  CASH FLOW 대 총자본비율
# 6    253.102270         총자본정상영업이익률
# 7     97.900000               유동비율
# 8     95.588407               당좌비율
# 9     47.276404               수지비율
# 10    11.119551             총자본증가율
# 11     9.299289            자기자본증가율
# 12     6.473993             1주당순자산
# 13     5.889640           순운전자본회전률
# 14     5.807999               현금비율
# 15     5.647646            종업원수증가율
# 16     4.175915             1주당매출액
# 17     2.709431                유보율
# 18     1.932693  CASH FLOW 대 차입금비율
# 19     1.891862           노동장비율_계산
# 20     1.647393           기계장비율_계산
# 21     1.559637             매출액증가율
# 22     1.352660               부채비율
# 23     1.083887           자본집약도_계산
# 24     1.010021      매출채권 대 매입채무비율
# 25     1.004083            재고자산회전률
# 26     1.001646            매출채권회전률

# %%
# 재무비율이 아닌 컬럼
no_finan_list = df_part7.columns[:10].tolist()

# %%
# 유의한 컬럼
feature_vif_list = feature_vif_df['Feature'].tolist()

# %%
logit_vif = pd.DataFrame()
logit_vif[no_finan_list] = df_part7[no_finan_list]
logit_vif[feature_vif_list] = df_part7[feature_vif_list]
logit_vif.to_csv('../data/유의성/dataset1_raw_mm_logit_vif.csv', index=False, encoding='CP949')

# %%
logit_vif
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# %% [markdown]
# ### MinMaxScaler 등분산, 이분산 확인

# %% [markdown]
# ## Bartlett

# %%
scaled_df_part7['부실기업'] = df_part7.iloc[:, 7]
scaled_df_part7.head(5)
# Out:
#      총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  매출액정상영업이익률  \
# 0  0.038129 -0.006213 -0.026901  0.177793  0.001221   0.492988    0.002422
# 1  2.405612 -0.014917  0.133131 -0.088548 -0.109675  -0.284790   -0.394514
# 2 -0.338274  0.040588  0.087215  0.050893 -0.063794   0.249564    0.006057
# 3 -0.191536 -0.008832 -0.038818 -0.006584  0.329179  -0.010469   -0.020064
# 4 -0.351864 -0.057584 -0.049094  0.023538 -0.194854  -0.255806   -0.174233
#
#     매출액순이익률   총자본순이익률  총자본정상영업이익률  ...  자본집약도_계산    총자본회전률   자기자본회전률  \
# 0 -0.096454 -0.868161   -0.322687  ... -0.186750 -0.573517 -0.173354
# 1 -0.379481 -1.901359   -1.938114  ... -0.166846 -1.083230 -0.230282
# 2 -0.009725 -0.250268   -0.449773  ... -0.168088 -1.139865 -0.256014
# 3 -0.016349 -0.274578   -0.531003  ... -0.173221 -1.064352 -0.263276
# 4 -0.140037 -0.948183   -1.221457  ... -0.172471 -0.932204 -0.245956
#
#     타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률   매출채권회전률  순운전자본회전률  부실기업
# 0 -0.422910 -0.670420 -0.685081 -0.035909 -0.020210 -0.575575     0
# 1 -0.933345 -1.275654 -1.194169 -0.035989 -0.020429 -1.311001     0
# 2 -0.777379 -1.308817 -1.220143 -0.036025 -0.020349 -1.311001     0
# 3 -0.025904 -1.143000 -1.074689 -0.036094 -0.020425 -1.077002     0
# 4 -0.011726 -0.885983 -0.856509 -0.036044 -0.020338 -0.759431     0
#
# [5 rows x 50 columns]

# %%
from scipy.stats import bartlett

homosced = []
heterosced = []

bart_df = scaled_df_part7.iloc[:, 10:]

nc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==0]  # normal company 
bc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==1]  # bankrupt company

bart_sced_df = pd.DataFrame(index=['등분산성'])

for i in bart_df.columns:
    bart_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    bartresult = np.round(bartlett(ser_1, ser_2)[1], 3)
    
    if bartresult < 0.05:
        homosced.append(i)
        bart_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", bartresult,"-> 등분산")
    else:
        heterosced.append(i)
        bart_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", bartresult,"-> 이분산")
        
    print("**********************************************************")
# Out:
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 금융비용부담률 pvalue 0.0 -> 등분산
# **********************************************************
# 수지비율 pvalue 0.0 -> 등분산
# **********************************************************
# 사내유보 대 자기자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당매출액 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순이익 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당 CASH FLOW pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순자산 pvalue 0.0 -> 등분산
# **********************************************************
# 유보율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본구성비율 pvalue 0.168 -> 이분산
# **********************************************************
# 유동비율 pvalue 0.052 -> 이분산
# **********************************************************
# 당좌비율 pvalue 0.036 -> 등분산
# **********************************************************
# 현금비율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출채권 대 매입채무비율 pvalue 0.0 -> 등분산
# **********************************************************
# 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# 이자보상배율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 차입금비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 총자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 매출액비율 pvalue 0.0 -> 등분산
# **********************************************************
# 재고자산대순운전자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 설비투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 기계투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 부가가치율 pvalue 0.0 -> 등분산
# **********************************************************
# 노동소득분배율 pvalue 0.0 -> 등분산
# **********************************************************
# 종업원1인당부가가치율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 노동장비율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 기계장비율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 자본집약도_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본회전률 pvalue 0.141 -> 이분산
# **********************************************************
# 자기자본회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 타인자본회전률 pvalue 0.542 -> 이분산
# **********************************************************
# 유동자산회전률 pvalue 0.043 -> 등분산
# **********************************************************
# 당좌자산회전률 pvalue 0.001 -> 등분산
# **********************************************************
# 재고자산회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 매출채권회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 순운전자본회전률 pvalue 0.446 -> 이분산
# **********************************************************
# 부실기업 pvalue nan -> 이분산
# **********************************************************
# c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:2468: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:2468: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)

# %%
# 피처별 등분산성 데이터프레임 생성
bart_sced_df = bart_sced_df.transpose()
bart_sced_df
# Out:
#                   등분산성
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           이분산
# 유동비율               이분산
# 당좌비율               등분산
# 현금비율               등분산
# 매출채권 대 매입채무비율      등분산
# 부채비율               등분산
# 이자보상배율             등분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  등분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       등분산
# 총자본투자효율            등분산
# 설비투자효율             등분산
# 기계투자효율             등분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     등분산
# 노동장비율_계산           등분산
# 기계장비율_계산           등분산
# 자본집약도_계산           등분산
# 총자본회전률             이분산
# 자기자본회전률            등분산
# 타인자본회전률            이분산
# 유동자산회전률            등분산
# 당좌자산회전률            등분산
# 재고자산회전률            등분산
# 매출채권회전률            등분산
# 순운전자본회전률           이분산
# 부실기업               이분산

# %%
bart_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     34
# 이분산      6
# dtype: int64

# %% [markdown]
# ### 이상치 제거 전 Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)

        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)

        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 금융비용부담률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 수지비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 사내유보 대 자기자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당매출액 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순이익 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당 CASH FLOW 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순자산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유보율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 당좌비율 의 pvalue: 0.417
# **********************************************************
# 등분산을 가정한 현금비율 의 pvalue: 0.634
# **********************************************************
# 등분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.619
# **********************************************************
# 등분산을 가정한 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 이자보상배율 의 pvalue: 0.097
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 차입금비율 의 pvalue: 0.51
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 총자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 매출액비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산대순운전자본비율 의 pvalue: 0.435
# **********************************************************
# 등분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 설비투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 기계투자효율 의 pvalue: 0.442
# **********************************************************
# 등분산을 가정한 부가가치율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동소득분배율 의 pvalue: 0.036
# **********************************************************
# 등분산을 가정한 종업원1인당부가가치율_계산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동장비율_계산 의 pvalue: 0.703
# **********************************************************
# 등분산을 가정한 기계장비율_계산 의 pvalue: 0.415
# **********************************************************
# 등분산을 가정한 자본집약도_계산 의 pvalue: 0.108
# **********************************************************
# 등분산을 가정한 자기자본회전률 의 pvalue: 0.733
# **********************************************************
# 등분산을 가정한 유동자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산회전률 의 pvalue: 0.009
# **********************************************************
# 등분산을 가정한 매출채권회전률 의 pvalue: 0.649
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  22 개
# ['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '유동자산회전률', '당좌자산회전률', '재고자산회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 이분산성 Welch's T-test
def ttest_hetero(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)

        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
            
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 자기자본구성비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 유동비율 의 pvalue: 0.14
# **********************************************************
# 이분산을 가정한 총자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 타인자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 순운전자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 부실기업 의 pvalue: 0.0
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  5 개
# ['자기자본구성비율', '총자본회전률', '타인자본회전률', '순운전자본회전률', '부실기업']

# %%
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처:  ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '유동자산회전률', '당좌자산회전률', '재고자산회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처:  ['자기자본구성비율', '총자본회전률', '타인자본회전률', '순운전자본회전률']

# %%
for i, col in enumerate(df_part7):
    print(i, col)
# Out:
# 0 회사명
# 1 거래소코드
# 2 회계년도
# 3 상장일
# 4 상장폐지일_x
# 5 부실기업1
# 6 부실기업2
# 7 부실기업
# 8 업종
# 9 경기민감도
# 10 총자본증가율
# 11 순이익증가율
# 12 자기자본증가율
# 13 매출액증가율
# 14 종업원수증가율
# 15 정상영업손익증가율
# 16 매출액정상영업이익률
# 17 매출액순이익률
# 18 총자본순이익률
# 19 총자본정상영업이익률
# 20 자기자본정상영업이익률
# 21 자기자본순이익률
# 22 금융비용부담률
# 23 수지비율
# 24 사내유보 대 자기자본비율
# 25 1주당매출액
# 26 1주당순이익
# 27 1주당 CASH FLOW
# 28 1주당순자산
# 29 유보율
# 30 자기자본구성비율
# 31 유동비율
# 32 당좌비율
# 33 현금비율
# 34 매출채권 대 매입채무비율
# 35 부채비율
# 36 이자보상배율
# 37 CASH FLOW 대 부채비율
# 38 CASH FLOW 대 차입금비율
# 39 CASH FLOW 대 총자본비율
# 40 CASH FLOW 대 매출액비율
# 41 재고자산대순운전자본비율
# 42 총자본투자효율
# 43 설비투자효율
# 44 기계투자효율
# 45 부가가치율
# 46 노동소득분배율
# 47 종업원1인당부가가치율_계산
# 48 노동장비율_계산
# 49 기계장비율_계산
# 50 자본집약도_계산
# 51 총자본회전률
# 52 자기자본회전률
# 53 타인자본회전률
# 54 유동자산회전률
# 55 당좌자산회전률
# 56 재고자산회전률
# 57 매출채권회전률
# 58 순운전자본회전률

# %%
df_ss_sig = pd.DataFrame()
df_ss_sig = df_part7.iloc[:, :10]
df_ss_sig[significant_homosced] = scaled_df_part7[significant_homosced]
df_ss_sig[significant_heterosced] = scaled_df_part7[significant_heterosced]

# %%
df_ss_sig
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        자기자본정상영업이익률  ...     부가가치율   노동소득분배율  종업원1인당부가가치율_계산   유동자산회전률  \
# 0        -0.291344  ... -0.080259  0.014457       -0.181412 -0.670420
# 1        -1.575307  ... -0.440954  0.915093       -0.217939 -1.275654
# 2        -0.388614  ...  0.216560  0.004401       -0.149999 -1.308817
# 3        -0.455134  ...  0.151070  0.007399       -0.160548 -1.143000
# 4        -0.848607  ... -0.152801  0.038685       -0.180766 -0.885983
# ...            ...  ...       ...       ...             ...       ...
# 12738     0.354402  ... -0.263226 -0.014198       -0.081396  2.587893
# 12739     0.210694  ... -0.254158 -0.008231       -0.082256  2.422076
# 12740     0.271566  ... -0.226955 -0.006795       -0.074437  3.126800
# 12741    -0.308916  ... -0.219298  0.001800       -0.103618  4.080250
# 12742    -1.043146  ... -0.363375  0.036901       -0.158318  4.660611
#
#         당좌자산회전률   재고자산회전률  자기자본구성비율    총자본회전률   타인자본회전률  순운전자본회전률
# 0     -0.685081 -0.035909  0.325597 -0.573517 -0.422910 -0.575575
# 1     -1.194169 -0.035989 -0.132178 -1.083230 -0.933345 -1.311001
# 2     -1.220143 -0.036025  1.246522 -1.139865 -0.777379 -1.311001
# 3     -1.074689 -0.036094  1.108114 -1.064352 -0.025904 -1.077002
# 4     -0.856509 -0.036044  1.040194 -0.932204 -0.011726 -0.759431
# ...         ...       ...       ...       ...       ...       ...
# 12738  1.470748 -0.030278 -1.331667  0.804597 -0.489077  1.363278
# 12739  1.335684 -0.029929 -1.392202  0.729084 -0.503256  1.379992
# 12740  1.823992 -0.028952 -1.559508  0.389275 -0.645044  1.580563
# 12741  2.644766 -0.030299 -1.635519 -0.026047 -0.805736  1.647420
# 12742  3.340865 -0.031686 -1.904883 -0.063804 -0.843547  1.480278
#
# [12743 rows x 35 columns]

# %%
df_ss_sig.to_csv('../data/유의성/mmscaler_data.csv', index=False, encoding='CP949')

# %% [markdown]
# ## Levene

# %%
scaled_df_part7['부실기업'] = df_part7.iloc[:, 7]
scaled_df_part7.head(5)
# Out:
#      총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  매출액정상영업이익률  \
# 0  0.038129 -0.006213 -0.026901  0.177793  0.001221   0.492988    0.002422
# 1  2.405612 -0.014917  0.133131 -0.088548 -0.109675  -0.284790   -0.394514
# 2 -0.338274  0.040588  0.087215  0.050893 -0.063794   0.249564    0.006057
# 3 -0.191536 -0.008832 -0.038818 -0.006584  0.329179  -0.010469   -0.020064
# 4 -0.351864 -0.057584 -0.049094  0.023538 -0.194854  -0.255806   -0.174233
#
#     매출액순이익률   총자본순이익률  총자본정상영업이익률  ...  자본집약도_계산    총자본회전률   자기자본회전률  \
# 0 -0.096454 -0.868161   -0.322687  ... -0.186750 -0.573517 -0.173354
# 1 -0.379481 -1.901359   -1.938114  ... -0.166846 -1.083230 -0.230282
# 2 -0.009725 -0.250268   -0.449773  ... -0.168088 -1.139865 -0.256014
# 3 -0.016349 -0.274578   -0.531003  ... -0.173221 -1.064352 -0.263276
# 4 -0.140037 -0.948183   -1.221457  ... -0.172471 -0.932204 -0.245956
#
#     타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률   매출채권회전률  순운전자본회전률  부실기업
# 0 -0.422910 -0.670420 -0.685081 -0.035909 -0.020210 -0.575575     0
# 1 -0.933345 -1.275654 -1.194169 -0.035989 -0.020429 -1.311001     0
# 2 -0.777379 -1.308817 -1.220143 -0.036025 -0.020349 -1.311001     0
# 3 -0.025904 -1.143000 -1.074689 -0.036094 -0.020425 -1.077002     0
# 4 -0.011726 -0.885983 -0.856509 -0.036044 -0.020338 -0.759431     0
#
# [5 rows x 50 columns]

# %%
from scipy.stats import levene

homosced = []
heterosced = []

lev_df = scaled_df_part7.iloc[:, :-1]

nc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==0]  # normal company 
bc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==1]  # bankrupt company

lev_sced_df = pd.DataFrame(index=['등분산성'])

for i in lev_df.columns:
    lev_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    lresult = np.round(levene(ser_1, ser_2)[1], 3)
    
    if lresult < 0.05:
        homosced.append(i)
        lev_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", lresult,"-> 등분산")
    else:
        heterosced.append(i)
        lev_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", lresult,"-> 이분산")

    print("**********************************************************")
# Out:
# 총자본증가율 pvalue 0.005 -> 등분산
# **********************************************************
# 순이익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액증가율 pvalue 0.496 -> 이분산
# **********************************************************
# 종업원수증가율 pvalue 0.006 -> 등분산
# **********************************************************
# 정상영업손익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 금융비용부담률 pvalue 0.0 -> 등분산
# **********************************************************
# 수지비율 pvalue 0.0 -> 등분산
# **********************************************************
# 사내유보 대 자기자본비율 pvalue 0.002 -> 등분산
# **********************************************************
# 1주당매출액 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순이익 pvalue 0.011 -> 등분산
# **********************************************************
# 1주당 CASH FLOW pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순자산 pvalue 0.0 -> 등분산
# **********************************************************
# 유보율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본구성비율 pvalue 0.0 -> 등분산
# **********************************************************
# 유동비율 pvalue 0.815 -> 이분산
# **********************************************************
# 당좌비율 pvalue 0.566 -> 이분산
# **********************************************************
# 현금비율 pvalue 0.777 -> 이분산
# **********************************************************
# 매출채권 대 매입채무비율 pvalue 0.626 -> 이분산
# **********************************************************
# 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# 이자보상배율 pvalue 0.823 -> 이분산
# **********************************************************
# CASH FLOW 대 부채비율 pvalue 0.021 -> 등분산
# **********************************************************
# CASH FLOW 대 차입금비율 pvalue 0.494 -> 이분산
# **********************************************************
# CASH FLOW 대 총자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 매출액비율 pvalue 0.0 -> 등분산
# **********************************************************
# 재고자산대순운전자본비율 pvalue 0.303 -> 이분산
# **********************************************************
# 총자본투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 설비투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 기계투자효율 pvalue 0.545 -> 이분산
# **********************************************************
# 부가가치율 pvalue 0.0 -> 등분산
# **********************************************************
# 노동소득분배율 pvalue 0.0 -> 등분산
# **********************************************************
# 종업원1인당부가가치율_계산 pvalue 0.658 -> 이분산
# **********************************************************
# 노동장비율_계산 pvalue 0.763 -> 이분산
# **********************************************************
# 기계장비율_계산 pvalue 0.525 -> 이분산
# **********************************************************
# 자본집약도_계산 pvalue 0.112 -> 이분산
# **********************************************************
# 총자본회전률 pvalue 0.004 -> 등분산
# **********************************************************
# 자기자본회전률 pvalue 0.612 -> 이분산
# **********************************************************
# 타인자본회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 유동자산회전률 pvalue 0.012 -> 등분산
# **********************************************************
# 당좌자산회전률 pvalue 0.092 -> 이분산
# **********************************************************
# 재고자산회전률 pvalue 0.009 -> 등분산
# **********************************************************
# 매출채권회전률 pvalue 0.653 -> 이분산
# **********************************************************
# 순운전자본회전률 pvalue 0.004 -> 등분산
# **********************************************************

# %%
# 피처별 등분산성 데이터프레임 생성
lev_sced_df = lev_sced_df.transpose()
lev_sced_df
# Out:
#                   등분산성
# 총자본증가율             등분산
# 순이익증가율             등분산
# 자기자본증가율            등분산
# 매출액증가율             이분산
# 종업원수증가율            등분산
# 정상영업손익증가율          등분산
# 매출액정상영업이익률         등분산
# 매출액순이익률            등분산
# 총자본순이익률            등분산
# 총자본정상영업이익률         등분산
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           등분산
# 유동비율               이분산
# 당좌비율               이분산
# 현금비율               이분산
# 매출채권 대 매입채무비율      이분산
# 부채비율               등분산
# 이자보상배율             이분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  이분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       이분산
# 총자본투자효율            등분산
# 설비투자효율             등분산
# 기계투자효율             이분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     이분산
# 노동장비율_계산           이분산
# 기계장비율_계산           이분산
# 자본집약도_계산           이분산
# 총자본회전률             등분산
# 자기자본회전률            이분산
# 타인자본회전률            등분산
# 유동자산회전률            등분산
# 당좌자산회전률            이분산
# 재고자산회전률            등분산
# 매출채권회전률            이분산
# 순운전자본회전률           등분산

# %%
lev_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     33
# 이분산     16
# dtype: int64

# %% [markdown]
# ### MinMaxScaler Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

welch_df = scaled_df_part7.iloc[:, :-1]

nc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)
        
        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)
            
        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 총자본증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 순이익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본증가율 의 pvalue: 0.006
# **********************************************************
# 등분산을 가정한 종업원수증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 정상영업손익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 금융비용부담률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 수지비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 사내유보 대 자기자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당매출액 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순이익 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당 CASH FLOW 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순자산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유보율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본구성비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 총자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 매출액비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 설비투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 부가가치율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동소득분배율 의 pvalue: 0.036
# **********************************************************
# 등분산을 가정한 총자본회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 타인자본회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유동자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산회전률 의 pvalue: 0.009
# **********************************************************
# 등분산을 가정한 순운전자본회전률 의 pvalue: 0.0
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  33 개
# ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

# welch_df = scaled_df_part7.iloc[:, :-1]

nc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 이분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)
        
        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
            
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 매출액증가율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 유동비율 의 pvalue: 0.14
# **********************************************************
# 이분산을 가정한 당좌비율 의 pvalue: 0.44
# **********************************************************
# 이분산을 가정한 현금비율 의 pvalue: 0.539
# **********************************************************
# 이분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.059
# **********************************************************
# 이분산을 가정한 이자보상배율 의 pvalue: 0.017
# **********************************************************
# 이분산을 가정한 CASH FLOW 대 차입금비율 의 pvalue: 0.65
# **********************************************************
# 이분산을 가정한 재고자산대순운전자본비율 의 pvalue: 0.567
# **********************************************************
# 이분산을 가정한 기계투자효율 의 pvalue: 0.055
# **********************************************************
# 이분산을 가정한 종업원1인당부가가치율_계산 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 노동장비율_계산 의 pvalue: 0.643
# **********************************************************
# 이분산을 가정한 기계장비율_계산 의 pvalue: 0.303
# **********************************************************
# 이분산을 가정한 자본집약도_계산 의 pvalue: 0.038
# **********************************************************
# 이분산을 가정한 자기자본회전률 의 pvalue: 0.538
# **********************************************************
# 이분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권회전률 의 pvalue: 0.072
# **********************************************************

# %%
# 유의한 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  5 개
# ['매출액증가율', '이자보상배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '당좌자산회전률']

# %%
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처:  ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처:  ['매출액증가율', '이자보상배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '당좌자산회전률']
