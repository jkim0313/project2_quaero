# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df_part7 = pd.read_csv('../data/데이터셋/dataset5_수축기_ver2.csv', encoding='CP949')
df_part7.drop(columns='Unnamed: 0', inplace=True)
df_part7
# Out:
#            회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0     (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1     (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2     (주)CMG제약  58820  201712  200108      NaN      0      0     0       제조업
# 3     (주)CMG제약  58820  201812  200108      NaN      0      0     0       제조업
# 4     (주)CMG제약  58820  201912  200108      NaN      0      0     0       제조업
# ...        ...    ...     ...     ...      ...    ...    ...   ...       ...
# 6609   흥구석유(주)  24060  201812  199412      NaN      0      0     0  도매 및 소매업
# 6610   흥구석유(주)  24060  201912  199412      NaN      0      0     0  도매 및 소매업
# 6611   흥아해운(주)   3280  201112  197606      NaN      0      0     0  운수 및 창고업
# 6612   흥아해운(주)   3280  201212  197606      NaN      0      0     0  운수 및 창고업
# 6613   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
# ...

# %% [markdown]
# ### inf, -inf 값 확인

# %%
import numpy as np
df_part7[(df_part7 == np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7[(df_part7 == -np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 상장일                     0
# 상장폐지일_x              6337
# 부실기업1                   0
# 부실기업2                   0
# 부실기업                    0
# 업종                      0
# 경기민감도                   0
# 총자본증가율                  0
# 순이익증가율                  0
# 자기자본증가율                 0
# 매출액증가율                  0
# 종업원수증가율                 0
# 정상영업손익증가율               0
# 매출액정상영업이익률              0
# 매출액순이익률                 0
# 총자본순이익률                 0
# 총자본정상영업이익률              0
# 자기자본정상영업이익률             0
# 자기자본순이익률                0
# 금융비용부담률                 0
# 수지비율                    0
# 사내유보 대 자기자본비율           0
# 1주당매출액                  0
# 1주당순이익                  0
# 1주당 CASH FLOW           0
# 1주당순자산                  0
# 유보율                     0
# 자기자본구성비율                0
# 유동비율                    0
# 당좌비율                    0
# 현금비율                    0
# 매출채권 대 매입채무비율           0
# ...

# %% [markdown]
# ## 윈저라이징

# %%
wins_df_part7 = df_part7.copy()

# %%
# 윈저라이징 할 컬럼 데이터프레임
wins_df_part7 = wins_df_part7.iloc[:, 10:]

# %%
from scipy.stats.mstats import winsorize

# 윈저라이징 함수 생성
def winsorize_col(winsordf, col):
    winsordf[col] = winsorize(winsordf[col], limits=[0.025, 0.025])

# %%
# 윈저라이징 적용
for i in wins_df_part7.columns:
    winsorize_col(wins_df_part7, i)

# %%
wins_df = pd.DataFrame()
wins_df = df_part7.iloc[:, :10]
wins_df[wins_df_part7.columns.tolist()] = wins_df_part7[wins_df_part7.columns.tolist()]
wins_df
# Out:
#            회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0     (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1     (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2     (주)CMG제약  58820  201712  200108      NaN      0      0     0       제조업
# 3     (주)CMG제약  58820  201812  200108      NaN      0      0     0       제조업
# 4     (주)CMG제약  58820  201912  200108      NaN      0      0     0       제조업
# ...        ...    ...     ...     ...      ...    ...    ...   ...       ...
# 6609   흥구석유(주)  24060  201812  199412      NaN      0      0     0  도매 및 소매업
# 6610   흥구석유(주)  24060  201912  199412      NaN      0      0     0  도매 및 소매업
# 6611   흥아해운(주)   3280  201112  197606      NaN      0      0     0  운수 및 창고업
# 6612   흥아해운(주)   3280  201212  197606      NaN      0      0     0  운수 및 창고업
# 6613   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
# ...

# %% [markdown]
# ### 윈저라이징 후 히스토그램

# %%
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(wins_df_part7, axs.T.ravel()):
    sns.distplot(wins_df_part7[col], ax=ax)

plt.show()

# %% [markdown]
# ### 윈저라이징 후 박스플롯

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(wins_df_part7.columns, axs.T.ravel()):
    wins_df_part7[[col]].boxplot(ax=ax)

plt.show()

# %% [markdown]
# ### 윈저라이징 후 Q-Q Plot

# %%
from scipy import stats

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 10

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for ax, i in zip(axs.ravel(), wins_df_part7):
        stats.probplot(wins_df_part7[i], dist='norm', plot=ax)
        ax.set_title(str(i))

plt.show()

# %% [markdown]
# ### 윈저라이징 K-S Test

# %%
import numpy as np
from scipy.stats import kstest

def ks_test(df_name):
    ks_columns = []
    ks_columns.append([col for col in df_name])
    for i in ks_columns:
        for j in i:
            ks_test = kstest(df_name[j], 'norm')
            print(j, "의 pvalue:", ks_test.pvalue)

# %%
ks_test(wins_df_part7)
# Out:
# 총자본증가율 의 pvalue: 0.0
# 순이익증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액증가율 의 pvalue: 0.0
# 종업원수증가율 의 pvalue: 0.0
# 정상영업손익증가율 의 pvalue: 0.0
# 매출액정상영업이익률 의 pvalue: 0.0
# 매출액순이익률 의 pvalue: 0.0
# 총자본순이익률 의 pvalue: 0.0
# 총자본정상영업이익률 의 pvalue: 0.0
# 자기자본정상영업이익률 의 pvalue: 0.0
# 자기자본순이익률 의 pvalue: 0.0
# 금융비용부담률 의 pvalue: 1.628555164044302e-232
# 수지비율 의 pvalue: 0.0
# 사내유보 대 자기자본비율 의 pvalue: 0.0
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 0.0
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 0.0
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 0.0
# CASH FLOW 대 매출액비율 의 pvalue: 0.0
# 재고자산대순운전자본비율 의 pvalue: 0.0
# 총자본투자효율 의 pvalue: 0.0
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# 부가가치율 의 pvalue: 0.0
# 노동소득분배율 의 pvalue: 0.0
# 종업원1인당부가가치율_계산 의 pvalue: 0.0
# ...

# %% [markdown]
# ### 윈저라이징 Shapiro–Wilk test

# %%
# pvalue 함수

from scipy import stats
from scipy.stats import shapiro

# 등락률 컬럼만 추출해서 pvalue 구하는 함수
def shap_pct(df_name):
    pct_columns = []
    pct_columns.append([col for col in df_name])
    for i in pct_columns:
        for j in i:
            shapiro_test = shapiro(df_name[j])
            print(j, "의 pvalue:", shapiro_test.pvalue)

# %%
# 컬럼별 pvalue 값 출력
shap_pct(wins_df_part7)
# Out:
# 총자본증가율 의 pvalue: 0.0
# 순이익증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액증가율 의 pvalue: 0.0
# 종업원수증가율 의 pvalue: 0.0
# 정상영업손익증가율 의 pvalue: 0.0
# 매출액정상영업이익률 의 pvalue: 0.0
# 매출액순이익률 의 pvalue: 0.0
# 총자본순이익률 의 pvalue: 0.0
# 총자본정상영업이익률 의 pvalue: 4.203895392974451e-45
# 자기자본정상영업이익률 의 pvalue: 0.0
# 자기자본순이익률 의 pvalue: 0.0
# 금융비용부담률 의 pvalue: 0.0
# 수지비율 의 pvalue: 0.0
# 사내유보 대 자기자본비율 의 pvalue: 0.0
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 1.401298464324817e-44
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 0.0
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 1.312981204529491e-30
# CASH FLOW 대 매출액비율 의 pvalue: 1.2751816025355835e-43
# 재고자산대순운전자본비율 의 pvalue: 0.0
# 총자본투자효율 의 pvalue: 1.2387478424631383e-42
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# ...

# %% [markdown]
# ## Logit T 검정

# %%
# 로짓모듈가져와서 진행 
import statsmodels.api as sm

# 피처값만 데이터프레임에 불러오기
df_wins_sig_copy = wins_df.copy() 
x = df_wins_sig_copy.iloc[:, 10:]

#  상수항 추가
x = sm.add_constant(x, has_constant = "add")
log_reg = sm.Logit(df_wins_sig_copy['부실기업'], x).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.177992
#          Iterations 10
#                            Logit Regression Results
# ...
# Dep. Variable:                   부실기업   No. Observations:                 6614
# Model:                          Logit   Df Residuals:                     6564
# Method:                           MLE   Df Model:                           49
# Date:                Sun, 02 Oct 2022   Pseudo R-squ.:                  0.3270
# Time:                        23:45:51   Log-Likelihood:                -1177.2
# converged:                       True   LL-Null:                       -1749.2
# Covariance Type:            nonrobust   LLR p-value:                2.167e-207
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -2.0298      1.338     -1.517      0.129      -4.653       0.593
# ...

# %%
#로짓분석상 유의한 변수만을 추출
p_value = pd.DataFrame(log_reg.pvalues)
print(p_value[p_value[0] < 0.05], '\n유의한 변수의 수 :' ,len(p_value[p_value[0] < 0.05]))
# Out:
#                           0
# 총자본증가율             0.000261
# 자기자본증가율            0.000456
# 매출액증가율             0.000032
# 정상영업손익증가율          0.000001
# 자기자본정상영업이익률        0.024082
# 금융비용부담률            0.005827
# 1주당순이익             0.002122
# 유동비율               0.006300
# 당좌비율               0.002329
# CASH FLOW 대 부채비율   0.004153
# CASH FLOW 대 매출액비율  0.005533
# 재고자산대순운전자본비율       0.003571
# 노동장비율_계산           0.018527
# 매출채권회전률            0.007203
# 순운전자본회전률           0.010494
# 유의한 변수의 수 : 15

# %%
# 4-1) VIF

import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def feature_engineering_XbyVIF(df_cols):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(df_cols.values, i)
                        for i in range(df_cols.shape[1])]
    vif['Feature'] = df_cols.columns
    return vif

# %%
# 4-2) VIf 데이터프레임 확인
feature_vif = feature_engineering_XbyVIF(wins_df.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#     VIF_Factor            Feature
# 0   194.376122               수지비율
# 1   156.687615           자기자본구성비율
# 2    91.942601           순운전자본회전률
# 3    83.985097               유동비율
# 4    81.224891            유동자산회전률
# 5    71.096217               당좌비율
# 6    64.381731         총자본정상영업이익률
# 7    50.316032            총자본순이익률
# 8    46.624296             총자본회전률
# 9    30.524731            총자본투자효율
# 10   30.379323            당좌자산회전률
# 11   28.881887              부가가치율
# 12   28.278127            타인자본회전률
# 13   26.701445        자기자본정상영업이익률
# 14   25.892003         매출액정상영업이익률
# 15   23.299990            매출액순이익률
# 16   19.797967           자기자본순이익률
# 17   16.693951               부채비율
# 18   16.349611  CASH FLOW 대 총자본비율
# 19   13.148536  CASH FLOW 대 매출액비율
# 20   11.102717   CASH FLOW 대 부채비율
# 21    8.294895             1주당순자산
# 22    7.679585             1주당매출액
# 23    7.439584            자기자본회전률
# 24    5.568037     종업원1인당부가가치율_계산
# 25    4.276644           노동장비율_계산
# ...

# %%
wins_vif = wins_df.drop(['수지비율',
'자기자본구성비율',
'순운전자본회전률',
'유동자산회전률',
'총자본회전률',
'총자본투자효율',
'당좌자산회전률',
'부가가치율',
'매출액정상영업이익률',
'타인자본회전률',
'매출액순이익률',
'CASH FLOW 대 총자본비율',
'부채비율',
'자기자본순이익률',
'자기자본회전률'],axis=1)

# %%
# 4-2) VIf 데이터프레임 재확인
feature_vif = feature_engineering_XbyVIF(wins_vif.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#     VIF_Factor            Feature
# 0    52.509800               유동비율
# 1    50.222720               당좌비율
# 2    21.376711         총자본정상영업이익률
# 3    13.539554        자기자본정상영업이익률
# 4     7.475685             1주당순자산
# 5     7.423020            총자본순이익률
# 6     7.333370   CASH FLOW 대 부채비율
# 7     6.303726             1주당매출액
# 8     5.205445     종업원1인당부가가치율_계산
# 9     4.840903  CASH FLOW 대 매출액비율
# 10    4.182165             1주당순이익
# 11    4.049147               현금비율
# 12    3.956633      1주당 CASH FLOW
# 13    3.686887           노동장비율_계산
# 14    3.031991                유보율
# 15    2.731635             총자본증가율
# 16    2.722795            자기자본증가율
# 17    2.581016           자본집약도_계산
# 18    2.468027            노동소득분배율
# 19    2.449935            매출채권회전률
# 20    2.448556           기계장비율_계산
# 21    2.384370      사내유보 대 자기자본비율
# 22    1.853658             순이익증가율
# 23    1.843794            금융비용부담률
# 24    1.812526      매출채권 대 매입채무비율
# 25    1.698999             매출액증가율
# ...

# %%
# 재무비율이 아닌 컬럼
no_finan_list = df_part7.columns[:10].tolist()

# %%
# 유의한 컬럼
feature_vif_list = feature_vif_df['Feature'].tolist()

# %%
logit_vif = pd.DataFrame()
logit_vif[no_finan_list] = df_part7[no_finan_list]
logit_vif[feature_vif_list] = wins_df_part7[feature_vif_list]
logit_vif.to_csv('../data/유의성/dataset5_wins_logit_vif.csv', index=False, encoding='CP949')

# %%
logit_vif
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
# ...

# %% [markdown]
# ### 윈저라이징 등분산, 이분산 확인

# %%
wins_df_part7['부실기업'] = df_part7.iloc[:, 7]
wins_df_part7.head(5)
# Out:
#       총자본증가율      순이익증가율    자기자본증가율     매출액증가율  종업원수증가율   정상영업손익증가율  \
# 0  13.166482   80.280163   5.219839  56.396905     4.65  594.671706
# 1  78.275781 -341.571868  75.170505  -8.429134    -0.74 -432.398636
# 2  -2.093352  794.754625  55.100407  25.510008     1.49  594.671706
# 3   3.855597  -46.641074   0.010946  11.520576    20.59  -44.098325
# 4  -2.644307 -981.272492  -4.480893  18.851969    -4.88 -432.398636
#
#    매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  ...    자본집약도_계산  총자본회전률  \
# 0        3.61    -8.50    -5.58        2.37  ...  204.066667    0.66
# 1      -20.38   -33.87   -15.78       -9.96  ...  425.291045    0.39
# 2        3.88     1.45     0.52        1.40  ...  411.485294    0.36
# 3        1.94     0.69     0.28        0.78  ...  354.432927    0.40
# 4       -9.51   -13.50    -6.37       -4.49  ...  362.769231    0.47
#
#     자기자본회전률  타인자본회전률  유동자산회전률  당좌자산회전률  재고자산회전률  매출채권회전률  순운전자본회전률  부실기업
# ...

# %% [markdown]
# ## Bartlett

# %%
from scipy.stats import bartlett

homosced = []
heterosced = []

bart_df = wins_df_part7.iloc[:, 10:]

nc_df = wins_df_part7[wins_df_part7['부실기업'] ==0]  # normal company 
bc_df = wins_df_part7[wins_df_part7['부실기업'] ==1]  # bankrupt company

bart_sced_df = pd.DataFrame(index=['등분산성'])

for i in bart_df.columns:
    bart_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    bartresult = np.round(bartlett(ser_1, ser_2)[1], 3)
    
    if bartresult < 0.05:
        homosced.append(i)
        bart_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", bartresult,"-> 등분산")
    else:
        heterosced.append(i)
        bart_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", bartresult,"-> 이분산")
        
    print("**********************************************************")
# Out:
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 금융비용부담률 pvalue 0.0 -> 등분산
# **********************************************************
# 수지비율 pvalue 0.0 -> 등분산
# **********************************************************
# 사내유보 대 자기자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당매출액 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순이익 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당 CASH FLOW pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순자산 pvalue 0.0 -> 등분산
# **********************************************************
# 유보율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본구성비율 pvalue 0.0 -> 등분산
# **********************************************************
# ...

# %%
# 피처별 등분산성 데이터프레임 생성
bart_sced_df = bart_sced_df.transpose()
bart_sced_df
# Out:
#                   등분산성
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           등분산
# 유동비율               이분산
# 당좌비율               이분산
# 현금비율               이분산
# 매출채권 대 매입채무비율      이분산
# 부채비율               등분산
# 이자보상배율             등분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  등분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       등분산
# 총자본투자효율            이분산
# 설비투자효율             등분산
# 기계투자효율             등분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     등분산
# 노동장비율_계산           이분산
# 기계장비율_계산           이분산
# 자본집약도_계산           등분산
# 총자본회전률             등분산
# 자기자본회전률            이분산
# 타인자본회전률            등분산
# 유동자산회전률            등분산
# 당좌자산회전률            이분산
# 재고자산회전률            등분산
# 매출채권회전률            이분산
# 순운전자본회전률           등분산
# ...

# %%
bart_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     29
# 이분산     11
# dtype: int64

# %% [markdown]
# ### 이상치 제거 전 Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_homosced_df = wins_df_part7.loc[:, homosced][wins_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = wins_df_part7.loc[:, homosced][wins_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)
        
        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)
        
        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 금융비용부담률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 수지비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 사내유보 대 자기자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당매출액 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순이익 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당 CASH FLOW 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순자산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유보율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본구성비율 의 pvalue: 0.0
# ...

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  28 개
# ['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_heterosced_df = wins_df_part7.loc[:, heterosced][wins_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = wins_df_part7.loc[:, heterosced][wins_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 이분산성 Welch's T-test
def ttest_hetero(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)
        
        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
        
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 유동비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 당좌비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 현금비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.095
# **********************************************************
# 이분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 노동장비율_계산 의 pvalue: 0.996
# **********************************************************
# 이분산을 가정한 기계장비율_계산 의 pvalue: 0.872
# **********************************************************
# 이분산을 가정한 자기자본회전률 의 pvalue: 0.426
# **********************************************************
# 이분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권회전률 의 pvalue: 0.208
# **********************************************************
# 이분산을 가정한 부실기업 의 pvalue: 0.0
# ...

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  6 개
# ['유동비율', '당좌비율', '현금비율', '총자본투자효율', '당좌자산회전률', '부실기업']

# %%
print('등분산 유의수준 피처 개수: ', len(significant_homosced), '개')
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처 개수: ', len(significant_heterosced), '개')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처 개수:  28 개
# 등분산 유의수준 피처:  ['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처 개수:  6 개
# 이분산 유의수준 피처:  ['유동비율', '당좌비율', '현금비율', '총자본투자효율', '당좌자산회전률', '부실기업']

# %%
for i, col in enumerate(df_part7):
    print(i, col)
# Out:
# 0 회사명
# 1 거래소코드
# 2 회계년도
# 3 상장일
# 4 상장폐지일_x
# 5 부실기업1
# 6 부실기업2
# 7 부실기업
# 8 업종
# 9 경기민감도
# 10 총자본증가율
# 11 순이익증가율
# 12 자기자본증가율
# 13 매출액증가율
# 14 종업원수증가율
# 15 정상영업손익증가율
# 16 매출액정상영업이익률
# 17 매출액순이익률
# 18 총자본순이익률
# 19 총자본정상영업이익률
# 20 자기자본정상영업이익률
# 21 자기자본순이익률
# 22 금융비용부담률
# 23 수지비율
# 24 사내유보 대 자기자본비율
# 25 1주당매출액
# 26 1주당순이익
# 27 1주당 CASH FLOW
# 28 1주당순자산
# 29 유보율
# 30 자기자본구성비율
# 31 유동비율
# 32 당좌비율
# 33 현금비율
# 34 매출채권 대 매입채무비율
# 35 부채비율
# 36 이자보상배율
# 37 CASH FLOW 대 부채비율
# 38 CASH FLOW 대 차입금비율
# 39 CASH FLOW 대 총자본비율
# 40 CASH FLOW 대 매출액비율
# 41 재고자산대순운전자본비율
# 42 총자본투자효율
# 43 설비투자효율
# 44 기계투자효율
# 45 부가가치율
# 46 노동소득분배율
# 47 종업원1인당부가가치율_계산
# 48 노동장비율_계산
# 49 기계장비율_계산
# 50 자본집약도_계산
# 51 총자본회전률
# 52 자기자본회전률
# 53 타인자본회전률
# 54 유동자산회전률
# 55 당좌자산회전률
# 56 재고자산회전률
# 57 매출채권회전률
# 58 순운전자본회전률

# %%
df_wins_sig = pd.DataFrame()
df_wins_sig = df_part7.iloc[:, :10]
df_wins_sig[significant_homosced] = wins_df_part7[significant_homosced]
df_wins_sig[significant_heterosced] = wins_df_part7[significant_heterosced]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\project2_quaero\정규성검정\winsorized_normality_test.ipynb 셀 40 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/project2_quaero/%EC%A0%95%EA%B7%9C%EC%84%B1%EA%B2%80%EC%A0%95/winsorized_normality_test.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> df_wins_sig = pd.DataFrame()
#       <a href='vscode-notebook-cell:/d%3A/project2_quaero/%EC%A0%95%EA%B7%9C%EC%84%B1%EA%B2%80%EC%A0%95/winsorized_normality_test.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> df_wins_sig = df_part7.iloc[:, :10]
# ----> <a href='vscode-notebook-cell:/d%3A/project2_quaero/%EC%A0%95%EA%B7%9C%EC%84%B1%EA%B2%80%EC%A0%95/winsorized_normality_test.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a> df_wins_sig[significant_homosced] = wins_df_part7[significant_homosced]
# ...

# %%
df_wins_sig.columns[10:]
# Out:
# Index(['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액',
#        '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율',
#        '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율',
#        'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율',
#        '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률',
#        '순운전자본회전률', '유동비율', '당좌비율', '현금비율', '총자본투자효율', '당좌자산회전률'],
#       dtype='object')

# %%
df_wins_sig
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
# ...

# %%
df_wins_sig.to_csv('../data/유의성/winsorized_data.csv', index=False, encoding='CP949')

# %% [markdown]
# ## 윈저라이징 전 VIF

# %%
# # VIF
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# # VIF 출력을 위한 데이터 프레임 형성
# vif = pd.DataFrame()

# # VIF 값과 각 Feature 이름에 대해 설정
# vif["VIF Factor"] = [variance_inflation_factor(df_part7.iloc[:, 10:].values, i) for i in range(df_part7.iloc[:, 10:].shape[1])]
# vif["Feature"] = df_part7.iloc[:, 10:].columns 

# # VIF 값이 높은 순으로 정렬
# vif = vif.sort_values(by="VIF Factor", ascending=False).reset_index(drop=True)
# vif
# Out:
#     VIF Factor            Feature
# 0   129.810395               유동비율
# 1   120.759831               당좌비율
# 2    54.125929           순운전자본회전률
# 3    47.139877            유동자산회전률
# 4    20.344470               수지비율
# 5    18.264931            당좌자산회전률
# 6    17.078883           자기자본구성비율
# 7    16.260241             총자본회전률
# 8    11.514703            타인자본회전률
# 9     9.550933         총자본정상영업이익률
# 10    8.261016  CASH FLOW 대 매출액비율
# 11    7.432022              부가가치율
# 12    7.081388         매출액정상영업이익률
# 13    6.468179               현금비율
# 14    5.874351            총자본투자효율
# 15    5.539225        자기자본정상영업이익률
# 16    5.179644             1주당매출액
# 17    4.938369             1주당순자산
# 18    4.738197            총자본순이익률
# 19    4.593502               부채비율
# 20    3.957466  CASH FLOW 대 총자본비율
# 21    3.789166      1주당 CASH FLOW
# 22    3.045961      사내유보 대 자기자본비율
# 23    2.897906            매출액순이익률
# 24    2.821560            자기자본회전률
# 25    2.585729             1주당순이익
# ...

# %%
# df_wins_sig.columns[10:]
# Out:
# Index(['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액',
#        '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율',
#        '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율',
#        'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율',
#        '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률',
#        '순운전자본회전률', '유동비율', '당좌비율', '현금비율', '총자본투자효율', '당좌자산회전률'],
#       dtype='object')

# %%
# 유의성 피처 데이터 프레임
df_wins_bool = pd.DataFrame()
df_wins_bool['Feature'] = feature_vif_df['Feature']
df_wins_bool['Significant'] = ''
for i in df_wins_bool.index:
    if df_wins_bool.loc[i, 'Feature'] in df_wins_sig.columns:
        df_wins_bool.loc[i, 'Significant'] = 1  # 유의한 피처
    else:
        df_wins_bool.loc[i, 'Significant'] = 0  # 유의하지않은 피처
df_wins_bool
# Out:
#               Feature Significant
# 0                유동비율           1
# 1                당좌비율           1
# 2            순운전자본회전률           1
# 3             유동자산회전률           1
# 4                수지비율           1
# 5             당좌자산회전률           1
# 6            자기자본구성비율           1
# 7              총자본회전률           1
# 8             타인자본회전률           1
# 9          총자본정상영업이익률           0
# 10  CASH FLOW 대 매출액비율           1
# 11              부가가치율           1
# 12         매출액정상영업이익률           0
# 13               현금비율           1
# 14            총자본투자효율           1
# 15        자기자본정상영업이익률           1
# 16             1주당매출액           1
# 17             1주당순자산           1
# 18            총자본순이익률           0
# 19               부채비율           1
# 20  CASH FLOW 대 총자본비율           1
# 21      1주당 CASH FLOW           1
# 22      사내유보 대 자기자본비율           1
# 23            매출액순이익률           0
# 24            자기자본회전률           0
# 25             1주당순이익           1
# ...

# %%
vif_sig = vif.copy()
vif_sig['Significant'] = df_wins_bool['Significant']
vif_sig
# Out:
#     VIF Factor            Feature Significant
# 0   129.810395               유동비율           1
# 1   120.759831               당좌비율           1
# 2    54.125929           순운전자본회전률           1
# 3    47.139877            유동자산회전률           1
# 4    20.344470               수지비율           1
# 5    18.264931            당좌자산회전률           1
# 6    17.078883           자기자본구성비율           1
# 7    16.260241             총자본회전률           1
# 8    11.514703            타인자본회전률           1
# 9     9.550933         총자본정상영업이익률           0
# 10    8.261016  CASH FLOW 대 매출액비율           1
# 11    7.432022              부가가치율           1
# 12    7.081388         매출액정상영업이익률           0
# 13    6.468179               현금비율           1
# 14    5.874351            총자본투자효율           1
# 15    5.539225        자기자본정상영업이익률           1
# 16    5.179644             1주당매출액           1
# 17    4.938369             1주당순자산           1
# 18    4.738197            총자본순이익률           0
# ...

# %% [markdown]
# ## 윈저라이징 후 VIF

# %%
# VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# VIF 출력을 위한 데이터 프레임 형성
vif = pd.DataFrame()

# VIF 값과 각 Feature 이름에 대해 설정
vif["VIF Factor"] = [variance_inflation_factor(wins_df_part7.iloc[:, 10:].values, i) for i in range(wins_df_part7.iloc[:, 10:].shape[1])]
vif["Feature"] = wins_df_part7.iloc[:, 10:].columns 

# VIF 값이 높은 순으로 정렬
vif = vif.sort_values(by="VIF Factor", ascending=False).reset_index(drop=True)
vif
# Out:
#     VIF Factor            Feature
# 0   138.484310               수지비율
# 1   120.564778           자기자본구성비율
# 2    87.575908           순운전자본회전률
# 3    81.980390               유동비율
# 4    76.330140            유동자산회전률
# 5    71.460626               당좌비율
# 6    45.937765             총자본회전률
# 7    29.847618            당좌자산회전률
# 8    27.741840            총자본투자효율
# 9    25.872129              부가가치율
# 10   25.426709            타인자본회전률
# 11   17.041831  CASH FLOW 대 총자본비율
# 12   14.140580               부채비율
# 13   13.413651  CASH FLOW 대 매출액비율
# 14   11.221982   CASH FLOW 대 부채비율
# 15    9.321113            자기자본회전률
# 16    8.199896             1주당순자산
# 17    7.619841             1주당매출액
# 18    6.327136        자기자본정상영업이익률
# 19    5.732184           자기자본순이익률
# 20    5.585400     종업원1인당부가가치율_계산
# 21    4.939889      1주당 CASH FLOW
# 22    4.647439            노동소득분배율
# 23    4.330525           노동장비율_계산
# 24    4.293143               현금비율
# 25    4.246602             1주당순이익
# ...

# %% [markdown]
# ## '----------------------------------------------------------'

# %% [markdown]
# ## Levene

# %%
wins_df_part7['부실기업'] = df_part7.iloc[:, 7]
wins_df_part7.head(5)
# Out:
#       총자본증가율      순이익증가율    자기자본증가율     매출액증가율  종업원수증가율   정상영업손익증가율  \
# 0  13.166482   80.280163   5.219839  56.396905     4.65  594.671706
# 1  78.275781 -341.571868  75.170505  -8.429134    -0.74 -432.398636
# 2  -2.093352  794.754625  55.100407  25.510008     1.49  594.671706
# 3   3.855597  -46.641074   0.010946  11.520576    20.59  -44.098325
# 4  -2.644307 -981.272492  -4.480893  18.851969    -4.88 -432.398636
#
#    매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  ...    자본집약도_계산  총자본회전률  \
# 0        3.61    -8.50    -5.58        2.37  ...  204.066667    0.66
# 1      -20.38   -33.87   -15.78       -9.96  ...  425.291045    0.39
# 2        3.88     1.45     0.52        1.40  ...  411.485294    0.36
# 3        1.94     0.69     0.28        0.78  ...  354.432927    0.40
# 4       -9.51   -13.50    -6.37       -4.49  ...  362.769231    0.47
#
#     자기자본회전률  타인자본회전률  유동자산회전률  당좌자산회전률  재고자산회전률  매출채권회전률  순운전자본회전률  부실기업
# ...

# %%
# from scipy.stats import bartlett
from scipy.stats import levene

homosced = []
heterosced = []

lev_df = wins_df_part7.iloc[:, :-1]

nc_df = wins_df_part7[wins_df_part7['부실기업'] ==0]  # normal company 
bc_df = wins_df_part7[wins_df_part7['부실기업'] ==1]  # bankrupt company

lev_sced_df = pd.DataFrame(index=['등분산성'])

for i in lev_df.columns:
    lev_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    lresult = np.round(levene(ser_1, ser_2)[1], 3)
    
    if lresult < 0.05:
        homosced.append(i)
        lev_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", lresult,"-> 등분산")
    else:
        heterosced.append(i)
        lev_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", lresult,"-> 이분산")
        
    print("**********************************************************")
# Out:
# 총자본증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 순이익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 종업원수증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 정상영업손익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본정상영업이익률 pvalue 0.003 -> 등분산
# **********************************************************
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# ...

# %%
# 피처별 등분산성 데이터프레임 생성
lev_sced_df = lev_sced_df.transpose()
lev_sced_df
# Out:
#                   등분산성
# 총자본증가율             등분산
# 순이익증가율             등분산
# 자기자본증가율            등분산
# 매출액증가율             등분산
# 종업원수증가율            등분산
# 정상영업손익증가율          등분산
# 매출액정상영업이익률         등분산
# 매출액순이익률            등분산
# 총자본순이익률            등분산
# 총자본정상영업이익률         등분산
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           등분산
# 유동비율               등분산
# 당좌비율               이분산
# 현금비율               등분산
# 매출채권 대 매입채무비율      이분산
# 부채비율               등분산
# 이자보상배율             등분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  등분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       이분산
# 총자본투자효율            이분산
# 설비투자효율             등분산
# 기계투자효율             등분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     등분산
# 노동장비율_계산           이분산
# ...

# %%
lev_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     40
# 이분산      9
# dtype: int64

# %% [markdown]
# ### 윈저라이징 Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

# welch_df = wins_df_part7.iloc[:, :-1]

nc_homosced_df = wins_df_part7.loc[:, homosced][wins_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = wins_df_part7.loc[:, homosced][wins_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)
            
        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)
            
        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 총자본증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 순이익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 종업원수증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 정상영업손익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# ...

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  40 개
# ['총자본증가율', '순이익증가율', '자기자본증가율', '매출액증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '유동비율', '현금비율', '부채비율', '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

# welch_df = wins_df_part7.iloc[:, :-1]

nc_heterosced_df = wins_df_part7.loc[:, heterosced][wins_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = wins_df_part7.loc[:, heterosced][wins_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_hetero(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)
        
        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
        
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 당좌비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.095
# **********************************************************
# 이분산을 가정한 재고자산대순운전자본비율 의 pvalue: 0.542
# **********************************************************
# 이분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 노동장비율_계산 의 pvalue: 0.996
# **********************************************************
# 이분산을 가정한 기계장비율_계산 의 pvalue: 0.872
# **********************************************************
# 이분산을 가정한 자기자본회전률 의 pvalue: 0.426
# **********************************************************
# 이분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권회전률 의 pvalue: 0.208
# **********************************************************

# %%
# 유의한 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  3 개
# ['당좌비율', '총자본투자효율', '당좌자산회전률']

# %%
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처:  ['총자본증가율', '순이익증가율', '자기자본증가율', '매출액증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '유동비율', '현금비율', '부채비율', '이자보상배율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 차입금비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '설비투자효율', '기계투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처:  ['당좌비율', '총자본투자효율', '당좌자산회전률']
