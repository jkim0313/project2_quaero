# %%
import pandas as pd 

pd.set_option('display.max_columns', None)

# %%
df_part7 = pd.read_csv('../data/데이터셋/dataset5_수축기_ver2.csv', encoding='CP949')
df_part7.drop(columns='Unnamed: 0', inplace=True)
df_part7
# Out:
#            회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0     (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1     (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2     (주)CMG제약  58820  201712  200108      NaN      0      0     0       제조업
# 3     (주)CMG제약  58820  201812  200108      NaN      0      0     0       제조업
# 4     (주)CMG제약  58820  201912  200108      NaN      0      0     0       제조업
# ...        ...    ...     ...     ...      ...    ...    ...   ...       ...
# 6609   흥구석유(주)  24060  201812  199412      NaN      0      0     0  도매 및 소매업
# 6610   흥구석유(주)  24060  201912  199412      NaN      0      0     0  도매 및 소매업
# 6611   흥아해운(주)   3280  201112  197606      NaN      0      0     0  운수 및 창고업
# 6612   흥아해운(주)   3280  201212  197606      NaN      0      0     0  운수 및 창고업
# 6613   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#       경기민감도      총자본증가율      순이익증가율    자기자본증가율     매출액증가율  종업원수증가율  \
# 0         1   13.166482   80.280163   5.219839  56.396905     4.65
# 1         1  109.147119 -341.571868  75.170505  -8.429134    -0.74
# 2         1   -1.272045   64.066740  -3.128959  25.980614    25.00
# 3         1    4.391538  113.941369   6.164569  20.053151    11.00
# 4         1   68.074285  -49.692268  73.259362  17.563295     8.56
# ...     ...         ...         ...        ...        ...      ...
# 6609      1   -5.889568   14.777489   0.986153   6.874950    -9.68
# 6610      1   11.243737  249.941113   9.311157  -9.349453    -5.95
# 6611      0  -32.130031 -254.878674 -48.586286 -17.515635    -2.82
# 6612      0    0.494938  231.051401  10.071441   6.161947     3.78
# 6613      0  -11.431409 -327.993526 -39.276758   0.562842    -2.23
#
#         정상영업손익증가율  매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  \
# 0     1263.950784        3.61    -8.50    -5.58        2.37         3.51
# 1     -756.819406      -25.87   -40.97   -15.78       -9.96       -16.95
# 2       -9.946307        3.75     6.83     2.57        1.41         1.57
# 3       64.750960        5.15    12.16     5.42        2.29         2.54
# 4        1.400176        4.44     5.20     1.99        1.70         1.83
# ...           ...         ...      ...      ...         ...          ...
# 6609    45.369913        0.66     1.43     3.06        1.41         1.56
# 6610   -54.160884        0.33     5.50    10.44        0.63         0.68
# 6611  -114.599191       -0.80    -2.95    -3.75       -1.01        -4.38
# 6612   116.606432        4.54     2.12     2.90        6.19        27.71
# 6613  -322.165979       -1.57    -8.79    -8.13       -1.45        -8.47
#
#       자기자본순이익률  금융비용부담률    수지비율  사내유보 대 자기자본비율        1주당매출액      1주당순이익  \
# 0        -8.28     0.80  108.35        -245.87    406.280703  -34.519834
# 1       -26.84     2.53  140.55        -165.71    246.198501 -100.872314
# 2         2.85    -2.72   93.31          -3.47    381.455040   26.035198
# 3         6.01    -1.01   92.86           2.22    457.948793   55.700060
# 4         2.15    -1.86   93.70           2.81    422.073107   21.967944
# ...        ...      ...     ...            ...           ...         ...
# 6609      3.38    -0.01   98.21          45.83  11080.553530  157.985933
# 6610     11.25    -0.12   93.28          50.44  10044.582330  552.857733
# 6611    -16.16     1.83  102.53          25.26   9677.535993 -285.731423
# 6612     12.96     1.88   97.39          22.17  10273.860650  218.030040
# 6613    -47.52     3.67  106.15          27.74   6549.252463 -575.510430
#
#       1주당 CASH FLOW       1주당순자산      유보율   자기자본구성비율     유동비율     당좌비율  \
# 0        -58.600377   418.623493   -17.45  66.046945   200.97   165.03
# 1        -23.817768   478.648111    -4.31  55.317408   693.49   649.98
# 2         17.890856   899.499302    79.90  89.390956   746.28   673.66
# 3          8.144012   954.951160    90.99  90.909211   957.86   856.94
# 4         20.327895  1297.106266   159.42  93.713752  1618.07  1520.84
# ...             ...          ...      ...        ...      ...      ...
# 6609     336.199133  4696.133333  4641.63  93.666279   329.17   290.09
# 6610      48.724867  5133.400000  5078.89  92.039062   485.39   422.76
# 6611     -81.729213  1499.177738   227.89  21.331523    62.54    54.80
# 6612     381.238939  1600.983010   260.15  23.364276    54.59    48.75
# 6613     -53.965366   842.628688    87.23  13.767987    35.76    29.58
#
#         현금비율  매출채권 대 매입채무비율    부채비율      이자보상배율  CASH FLOW 대 부채비율  \
# 0      15.10         602.31   51.41    3.530000            -46.08
# 1      68.81         323.41   80.77   -7.750000             -8.10
# 2      34.90         215.55   11.87   50.085714             22.67
# 3     158.50         414.65   10.00   50.085714             13.63
# 4     199.55         468.79    6.71  303.000000             15.35
# ...      ...            ...     ...         ...               ...
# 6609  105.67      139592.04    6.76   12.660000             69.29
# 6610   49.75       53375.77    8.65  252.020000             43.35
# 6611    4.96          65.47  368.79   -0.330000              3.15
# 6612    8.83          69.20  328.00    1.860000              2.59
# 6613    6.17          65.00  626.32   -0.420000             -0.57
#
#       CASH FLOW 대 차입금비율  CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  재고자산대순운전자본비율  \
# 0               -172.40             -15.65             -24.07     35.590076
# 1                -11.83              -3.62             -12.71      7.330001
# 2                  0.00               2.40               6.34     11.237105
# 3                  0.00               1.24               2.84     11.763349
# 4                647.74               0.96               3.16      6.405069
# ...                 ...                ...                ...           ...
# 6609               0.00               4.39               1.99    -39.085821
# 6610               0.00               3.45               1.92    -62.628126
# 6611               5.19               2.48               1.92    -20.666669
# 6612               4.07               1.98               1.46    -12.844650
# 6613              -1.53              -0.49              -0.50     -9.612150
#
#       총자본투자효율  설비투자효율        기계투자효율  부가가치율      노동소득분배율  종업원1인당부가가치율_계산  \
# 0       12.72   35.86  1.285100e+02  19.56    89.819047       27.179630
# 1        0.47    2.89  1.067000e+01   1.66  1749.845902       -0.657015
# 2       12.51   84.87  3.890800e+02  33.01    67.979294       68.550050
# 3       14.73  106.25  4.789100e+02  33.79    67.326482       75.890315
# 4        9.90  114.60  4.380500e+02  32.47    72.168603       78.976141
# ...       ...     ...           ...    ...          ...             ...
# 6609     9.80   19.56  3.064100e+03   4.44    47.471157       87.780000
# 6610    18.02   42.99  3.489210e+03  10.00    22.194040      190.794177
# 6611     6.92   14.67  7.882146e+05   5.37    83.089158       41.662267
# 6612    15.23   33.81  3.174389e+06  11.19    45.441565       98.506611
# 6613     5.43    8.35  1.535742e+09   5.51   131.187104       44.778480
#
#         노동장비율_계산   기계장비율_계산     자본집약도_계산  총자본회전률   자기자본회전률  타인자본회전률  유동자산회전률  \
# 0      71.503704  19.715837   204.066667    0.66  0.984333     2.01     1.25
# 1      69.134328  18.562172   425.291045    0.39  0.655130     0.93     0.52
# 2      80.915000  16.226510   547.840000    0.38  0.417335     3.86     0.52
# 3      77.788288  14.952423   515.225225    0.45  0.493892     4.53     0.61
# 4     100.078838  14.314319   797.688797    0.38  0.412632     5.21     0.51
# ...          ...        ...          ...     ...       ...      ...      ...
# 6609  448.809524   2.864786   895.309524    2.14  2.238746    22.28    11.71
# 6610  443.784810   5.468127  1059.000000    1.90  2.371074    26.38     8.58
# 6611  357.928779   0.000000   752.659884    1.27  1.466701     1.65     4.81
# 6612  331.240896   0.000000   720.803922    1.36  6.042220     1.76     5.82
# 6613  605.404995   0.000000   905.653637    0.93  4.550483     1.12     7.68
#
#       당좌자산회전률  재고자산회전률  매출채권회전률  순운전자본회전률
# 0        1.55     6.42     2.45      0.86
# 1        0.57     5.71     1.85      0.42
# 2        0.57     5.81     3.01      0.46
# 3        0.68     6.05     3.08      0.55
# 4        0.55     6.65     3.12      0.47
# ...       ...      ...      ...       ...
# 6609    13.76    78.35    31.01      8.08
# 6610     9.81    68.41    31.51      6.91
# 6611     5.31    50.91    27.43      2.05
# 6612     6.58    50.32    26.76      2.15
# 6613     9.30    44.09    23.08      2.09
#
# [6614 rows x 59 columns]

# %% [markdown]
# ### inf, -inf 값 확인

# %%
import numpy as np
df_part7[(df_part7 == np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7[(df_part7 == -np.inf).any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [회사명, 거래소코드, 회계년도, 상장일, 상장폐지일_x, 부실기업1, 부실기업2, 부실기업, 업종, 경기민감도, 총자본증가율, 순이익증가율, 자기자본증가율, 매출액증가율, 종업원수증가율, 정상영업손익증가율, 매출액정상영업이익률, 매출액순이익률, 총자본순이익률, 총자본정상영업이익률, 자기자본정상영업이익률, 자기자본순이익률, 금융비용부담률, 수지비율, 사내유보 대 자기자본비율, 1주당매출액, 1주당순이익, 1주당 CASH FLOW, 1주당순자산, 유보율, 자기자본구성비율, 유동비율, 당좌비율, 현금비율, 매출채권 대 매입채무비율, 부채비율, 이자보상배율, CASH FLOW 대 부채비율, CASH FLOW 대 차입금비율, CASH FLOW 대 총자본비율, CASH FLOW 대 매출액비율, 재고자산대순운전자본비율, 총자본투자효율, 설비투자효율, 기계투자효율, 부가가치율, 노동소득분배율, 종업원1인당부가가치율_계산, 노동장비율_계산, 기계장비율_계산, 자본집약도_계산, 총자본회전률, 자기자본회전률, 타인자본회전률, 유동자산회전률, 당좌자산회전률, 재고자산회전률, 매출채권회전률, 순운전자본회전률]
# Index: []

# %%
df_part7.isna().sum()
# Out:
# 회사명                     0
# 거래소코드                   0
# 회계년도                    0
# 상장일                     0
# 상장폐지일_x              6337
# 부실기업1                   0
# 부실기업2                   0
# 부실기업                    0
# 업종                      0
# 경기민감도                   0
# 총자본증가율                  0
# 순이익증가율                  0
# 자기자본증가율                 0
# 매출액증가율                  0
# 종업원수증가율                 0
# 정상영업손익증가율               0
# 매출액정상영업이익률              0
# 매출액순이익률                 0
# 총자본순이익률                 0
# 총자본정상영업이익률              0
# 자기자본정상영업이익률             0
# 자기자본순이익률                0
# 금융비용부담률                 0
# 수지비율                    0
# 사내유보 대 자기자본비율           0
# 1주당매출액                  0
# 1주당순이익                  0
# 1주당 CASH FLOW           0
# 1주당순자산                  0
# 유보율                     0
# 자기자본구성비율                0
# 유동비율                    0
# 당좌비율                    0
# 현금비율                    0
# 매출채권 대 매입채무비율           0
# 부채비율                    0
# 이자보상배율                  0
# CASH FLOW 대 부채비율        0
# CASH FLOW 대 차입금비율       0
# CASH FLOW 대 총자본비율       0
# CASH FLOW 대 매출액비율       0
# 재고자산대순운전자본비율            0
# 총자본투자효율                 0
# 설비투자효율                  0
# 기계투자효율                  0
# 부가가치율                   0
# 노동소득분배율                 0
# 종업원1인당부가가치율_계산          0
# 노동장비율_계산                0
# 기계장비율_계산                0
# 자본집약도_계산                0
# 총자본회전률                  0
# 자기자본회전률                 0
# 타인자본회전률                 0
# 유동자산회전률                 0
# 당좌자산회전률                 0
# 재고자산회전률                 0
# 매출채권회전률                 0
# 순운전자본회전률                0
# dtype: int64

# %% [markdown]
# ## 윈저라이징

# %%
wins_df_part7 = df_part7.copy()

# %%
# 윈저라이징 할 컬럼 데이터프레임
wins_df_part7 = wins_df_part7.iloc[:, 10:]

# %%
from scipy.stats.mstats import winsorize

# 윈저라이징 함수 생성
def winsorize_col(winsordf, col):
    winsordf[col] = winsorize(winsordf[col], limits=[0.025, 0.025])

# %%
# 윈저라이징 적용
for i in wins_df_part7.columns:
    winsorize_col(wins_df_part7, i)

# %%
wins_df = pd.DataFrame()
wins_df = df_part7.iloc[:, :10]
wins_df[wins_df_part7.columns.tolist()] = wins_df_part7[wins_df_part7.columns.tolist()]
wins_df
# Out:
#            회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0     (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1     (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2     (주)CMG제약  58820  201712  200108      NaN      0      0     0       제조업
# 3     (주)CMG제약  58820  201812  200108      NaN      0      0     0       제조업
# 4     (주)CMG제약  58820  201912  200108      NaN      0      0     0       제조업
# ...        ...    ...     ...     ...      ...    ...    ...   ...       ...
# 6609   흥구석유(주)  24060  201812  199412      NaN      0      0     0  도매 및 소매업
# 6610   흥구석유(주)  24060  201912  199412      NaN      0      0     0  도매 및 소매업
# 6611   흥아해운(주)   3280  201112  197606      NaN      0      0     0  운수 및 창고업
# 6612   흥아해운(주)   3280  201212  197606      NaN      0      0     0  운수 및 창고업
# 6613   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#       경기민감도     총자본증가율      순이익증가율    자기자본증가율     매출액증가율  종업원수증가율   정상영업손익증가율  \
# 0         1  13.166482   80.280163   5.219839  56.396905     4.65  692.776938
# 1         1  80.332825 -341.571868  75.170505  -8.429134    -0.74 -449.458852
# 2         1  -1.272045   64.066740  -3.128959  25.980614    25.00   -9.946307
# 3         1   4.391538  113.941369   6.164569  20.053151    11.00   64.750960
# 4         1  68.074285  -49.692268  73.259362  17.563295     8.56    1.400176
# ...     ...        ...         ...        ...        ...      ...         ...
# 6609      1  -5.889568   14.777489   0.986153   6.874950    -9.68   45.369913
# 6610      1  11.243737  249.941113   9.311157  -9.349453    -5.95  -54.160884
# 6611      0 -25.322990 -254.878674 -36.055069 -17.515635    -2.82 -114.599191
# 6612      0   0.494938  231.051401  10.071441   6.161947     3.78  116.606432
# 6613      0 -11.431409 -327.993526 -36.055069   0.562842    -2.23 -322.165979
#
#       매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  자기자본순이익률  \
# 0           3.61    -8.50    -5.58        2.37         3.51     -8.28
# 1         -22.59   -38.19   -15.78       -9.96       -16.95    -26.84
# 2           3.75     6.83     2.57        1.41         1.57      2.85
# 3           5.15    12.16     5.42        2.29         2.54      6.01
# 4           4.44     5.20     1.99        1.70         1.83      2.15
# ...          ...      ...      ...         ...          ...       ...
# 6609        0.66     1.43     3.06        1.41         1.56      3.38
# 6610        0.33     5.50    10.44        0.63         0.68     11.25
# 6611       -0.80    -2.95    -3.75       -1.01        -4.38    -16.16
# 6612        4.54     2.12     2.90        6.19        27.71     12.96
# 6613       -1.57    -8.79    -8.13       -1.45        -8.47    -46.61
#
#       금융비용부담률    수지비율  사내유보 대 자기자본비율        1주당매출액      1주당순이익  1주당 CASH FLOW  \
# 0        0.80  108.35        -112.34    596.921162  -34.519834     -58.600377
# 1        2.53  131.93        -112.34    596.921162 -100.872314     -23.817768
# 2       -2.72   93.31          -3.47    596.921162   26.035198      17.890856
# 3       -1.01   92.86           2.22    596.921162   55.700060       8.144012
# 4       -1.86   93.70           2.81    596.921162   21.967944      20.327895
# ...       ...     ...            ...           ...         ...            ...
# 6609    -0.01   98.21          45.83  11080.553530  157.985933     336.199133
# 6610    -0.12   93.28          50.44  10044.582330  552.857733      48.724867
# 6611     1.83  102.53          25.26   9677.535993 -285.731423     -81.729213
# 6612     1.88   97.39          22.17  10273.860650  218.030040     381.238939
# 6613     3.67  106.15          27.74   6549.252463 -575.510430     -53.965366
#
#            1주당순자산      유보율   자기자본구성비율     유동비율    당좌비율    현금비율  매출채권 대 매입채무비율  \
# 0      526.591549    10.42  66.046945   200.97  165.03   15.10         602.31
# 1      526.591549    10.42  55.317408   693.49  649.98   68.81         323.41
# 2      899.499302    79.90  89.390956   746.28  673.66   34.90         215.55
# 3      954.951160    90.99  90.909211   957.86  856.94  158.50         414.65
# 4     1297.106266   159.42  92.005000  1045.09  933.26  199.55         468.79
# ...           ...      ...        ...      ...     ...     ...            ...
# 6609  4696.133333  4641.63  92.005000   329.17  290.09  105.67        2189.35
# 6610  5133.400000  5078.89  92.005000   485.39  422.76   49.75        2189.35
# 6611  1499.177738   227.89  21.331523    62.54   54.80    4.96          65.47
# 6612  1600.983010   260.15  23.364276    54.59   48.75    8.83          69.20
# 6613   842.628688    87.23  19.261897    50.40   33.38    6.17          65.00
#
#         부채비율      이자보상배율  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0      51.41    3.530000            -22.84             -47.99
# 1      80.77   -7.750000             -8.10             -11.83
# 2      11.87   50.085714             22.67               0.00
# 3      10.00   50.085714             13.63               0.00
# 4       8.51  303.000000             15.35             647.74
# ...      ...         ...               ...                ...
# 6609    8.51   12.660000             69.29               0.00
# 6610    8.65  252.020000             43.35               0.00
# 6611  368.79   -0.330000              3.15               5.19
# 6612  328.00    1.860000              2.59               4.07
# 6613  407.99   -0.420000             -0.57              -1.53
#
#       CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  재고자산대순운전자본비율  총자본투자효율  설비투자효율  \
# 0                 -9.47             -15.79     35.590076    12.72   35.86
# 1                 -3.62             -12.71      7.330001     0.47    2.89
# 2                  2.40               6.34     11.237105    12.51   84.87
# 3                  1.24               2.84     11.763349    14.73  106.25
# 4                  0.96               3.16      6.405069     9.90  114.60
# ...                 ...                ...           ...      ...     ...
# 6609               4.39               1.99    -39.085821     9.80   19.56
# 6610               3.45               1.92    -62.628126    18.02   42.99
# 6611               2.48               1.92    -20.666669     6.92   14.67
# 6612               1.98               1.46    -12.844650    15.23   33.81
# 6613              -0.49              -0.50     -9.612150     5.43    8.35
#
#         기계투자효율  부가가치율     노동소득분배율  종업원1인당부가가치율_계산    노동장비율_계산   기계장비율_계산  \
# 0       128.51  19.56   89.819047       27.179630   71.503704  19.715837
# 1        10.67   1.66  171.323681       -0.657015   69.134328  18.562172
# 2       389.08  33.01   67.979294       68.550050   80.915000  16.226510
# 3       478.91  33.79   67.326482       75.890315   77.788288  14.952423
# 4       438.05  32.47   72.168603       78.976141  100.078838  14.314319
# ...        ...    ...         ...             ...         ...        ...
# 6609   3064.10   4.44   47.471157       87.780000  448.809524   2.864786
# 6610   3489.21  10.00   22.194040      190.794177  443.784810   5.468127
# 6611  89271.83   5.37   83.089158       41.662267  357.928779   0.000000
# 6612  89271.83  11.19   45.441565       98.506611  331.240896   0.000000
# 6613  89271.83   5.51  131.187104       44.778480  605.404995   0.000000
#
#          자본집약도_계산  총자본회전률   자기자본회전률  타인자본회전률  유동자산회전률  당좌자산회전률  재고자산회전률  \
# 0      204.066667    0.66  0.984333     2.01     1.25     1.55     6.42
# 1      425.291045    0.39  0.655130     0.93     0.52     0.57     5.71
# 2      547.840000    0.38  0.417335     3.86     0.52     0.57     5.81
# 3      515.225225    0.45  0.493892     4.53     0.61     0.68     6.05
# 4      797.688797    0.38  0.412632     5.21     0.51     0.55     6.65
# ...           ...     ...       ...      ...      ...      ...      ...
# 6609   895.309524    2.14  2.238746     8.08     4.88     7.53    78.35
# 6610  1059.000000    1.90  2.371074     8.08     4.88     7.53    68.41
# 6611   752.659884    1.27  1.466701     1.65     4.81     5.31    50.91
# 6612   720.803922    1.36  6.042220     1.76     4.88     6.58    50.32
# 6613   905.653637    0.93  4.550483     1.12     4.88     7.53    44.09
#
#       매출채권회전률  순운전자본회전률
# 0        2.45      0.86
# 1        1.85      0.42
# 2        3.01      0.46
# 3        3.08      0.55
# 4        3.12      0.47
# ...       ...       ...
# 6609    31.01      2.51
# 6610    31.51      2.51
# 6611    27.43      2.05
# 6612    26.76      2.15
# 6613    23.08      2.09
#
# [6614 rows x 59 columns]

# %% [markdown]
# ### RobustScaler

# %%
from sklearn.preprocessing import RobustScaler

rbscaler = RobustScaler()
rbscaler.fit(df_part7.iloc[:, 10:])

scaled_df_part7 = rbscaler.transform(df_part7.iloc[:, 10:])

scaled_df_part7 = pd.DataFrame(scaled_df_part7, columns=df_part7.iloc[:, 10:].columns)

# %%
scaled_df_part7
# Out:
#         총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  매출액정상영업이익률  \
# 0     0.398063  0.748807 -0.024544  2.342739  0.260207  13.934416   -0.152188
# 1     5.637333 -2.897275  4.577010 -0.648661 -0.195896  -8.290823   -3.890932
# 2    -0.390089  0.608673 -0.573751  0.939178  1.982230  -0.076414   -0.134432
# 3    -0.080933  1.039741  0.037603  0.665655  0.797546   0.745136    0.043120
# 4     3.395301 -0.374550  4.451290  0.550760  0.591073   0.048379   -0.046925
# ...        ...       ...       ...       ...       ...        ...         ...
# 6609 -0.642145  0.182665 -0.303048  0.057546 -0.952401   0.531976   -0.526316
# 6610  0.293106  2.215192  0.244595 -0.691129 -0.636768  -0.562704   -0.568167
# 6611 -2.074526 -2.147982 -3.564064 -1.067958 -0.371906  -1.227428   -0.711477
# 6612 -0.293635  2.051927  0.294609  0.024645  0.186588   1.315464   -0.034242
# 6613 -0.944656 -2.779917 -2.951656 -0.233726 -0.321980  -3.510331   -0.809131
#
#        매출액순이익률   총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  자기자본순이익률   금융비용부담률  \
# 0    -1.591153 -1.367601   -0.285290    -0.357484 -1.297020  0.292208
# 1    -5.943700 -2.956386   -2.117385    -1.986465 -3.025140  1.415584
# 2     0.463807 -0.098131   -0.427935    -0.511943 -0.260708 -1.993506
# 3     1.178284  0.345794   -0.297177    -0.434713  0.033520 -0.883117
# 4     0.245308 -0.188474   -0.384844    -0.491242 -0.325885 -1.435065
# ...        ...       ...         ...          ...       ...       ...
# 6609 -0.260054 -0.021807   -0.427935    -0.512739 -0.211359 -0.233766
# 6610  0.285523  1.127726   -0.543834    -0.582803  0.521415 -0.305195
# 6611 -0.847185 -1.082555   -0.787519    -0.985669 -2.030726  0.961039
# 6612 -0.167560 -0.046729    0.282318     1.569268  0.680633  0.993506
# 6613 -1.630027 -1.764798   -0.852897    -1.311306 -4.950652  2.155844
#
#           수지비율  사내유보 대 자기자본비율    1주당매출액    1주당순이익  1주당 CASH FLOW    1주당순자산  \
# 0     1.460840      -5.318817 -0.408475 -0.320483      -0.325586 -0.526825
# 1     5.115778      -3.810845 -0.415006 -0.372018      -0.307061 -0.521602
# 2    -0.246311      -0.758783 -0.409488 -0.273452      -0.284849 -0.484986
# 3    -0.297389      -0.651742 -0.406367 -0.250412      -0.290040 -0.480162
# 4    -0.202043      -0.640643 -0.407831 -0.276611      -0.283551 -0.450393
# ...        ...            ...       ...       ...            ...       ...
# 6609  0.309875       0.168650  0.027041 -0.170969      -0.115327 -0.154660
# 6610 -0.249716       0.255373 -0.015227  0.135719      -0.268427 -0.116616
# 6611  0.800227      -0.218314 -0.030203 -0.515593      -0.337903 -0.432811
# 6612  0.216799      -0.276443 -0.005872 -0.124334      -0.091340 -0.423954
# 6613  1.211124      -0.171660 -0.157838 -0.740657      -0.323117 -0.489934
#
#            유보율  자기자본구성비율      유동비율      당좌비율      현금비율  매출채권 대 매입채무비율  \
# 0    -0.696197  0.242806  0.230828  0.300405 -0.192736       1.816352
# 1    -0.687063 -0.089527  3.110809  3.654023  0.930024       0.564810
# 2    -0.628528  0.965855  3.419495  3.817779  0.221165       0.080796
# 3    -0.620820  1.012881  4.656697  5.085232  2.804912       0.974242
# 4    -0.573253  1.099748  8.517235  9.676360  3.663026       1.217191
# ...        ...       ...       ...       ...       ...            ...
# 6609  2.542373  1.098277  0.980470  1.165243  1.700549     625.522202
# 6610  2.846317  1.047876  1.893957  2.082708  0.531591     238.633243
# 6611 -0.525659 -1.142194 -0.578633 -0.461879 -0.404703      -0.592677
# 6612 -0.503235 -1.079232 -0.625121 -0.503717 -0.323805      -0.575938
# 6613 -0.623433 -1.376465 -0.735228 -0.636285 -0.379409      -0.594786
#
#           부채비율    이자보상배율  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0    -0.196555 -0.075922         -2.325436          -2.935918
# 1     0.092421 -0.452361         -0.793830          -0.450507
# 2    -0.585728  1.477748          0.447021          -0.267394
# 3    -0.604134  1.477748          0.082468          -0.267394
# 4    -0.636516  9.918071          0.151830           9.758765
# ...        ...       ...               ...                ...
# 6609 -0.636024  0.228767          2.327049          -0.267394
# 6610 -0.617421  8.216753          1.280976          -0.267394
# 6611  2.927264 -0.204739         -0.340155          -0.187060
# 6612  2.525787 -0.131654         -0.362738          -0.204396
# 6613  5.462008 -0.207742         -0.490170          -0.291077
#
#       CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  재고자산대순운전자본비율   총자본투자효율    설비투자효율  \
# 0             -2.820442          -3.181009      0.269460 -0.408208 -0.353712
# 1             -1.158840          -1.955220     -0.011609 -1.297984 -0.730997
# 2             -0.327348           0.100351      0.027251 -0.423461  0.207123
# 3             -0.487569          -0.277313      0.032485 -0.262212  0.451781
# 4             -0.526243          -0.242784     -0.020808 -0.613038  0.547332
# ...                 ...                ...           ...       ...       ...
# 6609          -0.052486          -0.369032     -0.473251 -0.620301 -0.540237
# 6610          -0.182320          -0.376585     -0.707398 -0.023243 -0.272121
# 6611          -0.316298          -0.376585     -0.290058 -0.829490 -0.596195
# 6612          -0.385359          -0.426221     -0.212262 -0.225894 -0.377171
# 6613          -0.726519          -0.637712     -0.180112 -0.937716 -0.668517
#
#             기계투자효율     부가가치율    노동소득분배율  종업원1인당부가가치율_계산  노동장비율_계산  기계장비율_계산  \
# 0    -1.496949e-01 -0.105859   1.138389       -0.777631 -0.352731  0.134402
# 1    -2.750150e-01 -1.070168  55.085349       -1.070866 -0.364556  0.109951
# 2     1.274151e-01  0.618721   0.428649       -0.341830 -0.305760  0.060446
# 3     2.229472e-01  0.660741   0.407434       -0.264507 -0.321365  0.033442
# 4     1.794935e-01  0.589630   0.564792       -0.232001 -0.210116  0.019918
# ...            ...       ...        ...             ...       ...       ...
# 6609  2.972235e+00 -0.920404  -0.237817       -0.139260  1.530355 -0.222754
# 6610  3.424330e+00 -0.620875  -1.059264        0.945904  1.505278 -0.167576
# 6611  8.379611e+02 -0.870303   0.919684       -0.625070  1.076781 -0.283473
# 6612  3.375601e+03 -0.556768  -0.303774       -0.026264  0.943585 -0.283473
# 6613  1.633225e+06 -0.862761   2.482754       -0.592243  2.311904 -0.283473
#
#       자본집약도_계산    총자본회전률   자기자본회전률    타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률  \
# 0    -0.593803 -0.379310 -0.335346  -0.155251 -0.449612 -0.460784 -0.162807
# 1    -0.320473 -0.844828 -0.560546  -0.648402 -1.015504 -0.941176 -0.229240
# 2    -0.169059 -0.862069 -0.723216   0.689498 -1.015504 -0.941176 -0.219883
# 3    -0.209356 -0.741379 -0.670845   0.995434 -0.945736 -0.887255 -0.197427
# 4     0.139637 -0.862069 -0.726433   1.305936 -1.023256 -0.950980 -0.141287
# ...        ...       ...       ...        ...       ...       ...       ...
# 6609  0.260251  2.172414  0.522767   9.100457  7.658915  5.524510  6.567485
# 6610  0.462496  1.758621  0.613289  10.972603  5.232558  3.588235  5.637427
# 6611  0.084003  0.672414 -0.005370  -0.319635  2.310078  1.382353  4.000000
# 6612  0.044643  0.827586  3.124629  -0.269406  3.093023  2.004902  3.944795
# 6613  0.273032  0.086207  2.104169  -0.561644  4.534884  3.338235  3.361871
#
#        매출채권회전률   순운전자본회전률
# 0    -0.784969  -0.406250
# 1    -0.910230  -1.093750
# 2    -0.668058  -1.031250
# 3    -0.653445  -0.890625
# 4    -0.645094  -1.015625
# ...        ...        ...
# 6609  5.177453  10.875000
# 6610  5.281837   9.046875
# 6611  4.430063   1.453125
# 6612  4.290188   1.609375
# 6613  3.521921   1.515625
#
# [6614 rows x 49 columns]

# %% [markdown]
# ### RobustScaler 히스토그램

# %%
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(scaled_df_part7, axs.T.ravel()):
    sns.distplot(scaled_df_part7[col], ax=ax)

plt.show()

# %% [markdown]
# ### RobustScaler 박스플롯

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 12

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for col, ax in zip(scaled_df_part7, axs.T.ravel()):
    scaled_df_part7[[col]].boxplot(ax=ax)

plt.show()

# %% [markdown]
# ### RobustScaler Q-Q Plot

# %%
from scipy import stats

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["font.family"] = "Malgun Gothic"

ncols = 5
nrows = 10

fig, axs = plt.subplots(nrows, ncols, constrained_layout=True)
fig.set_size_inches((50, 50))

for ax, i in zip(axs.ravel(), scaled_df_part7):
       stats.probplot(scaled_df_part7[i], dist=stats.norm, plot=ax)
       ax.set_title(str(i))

plt.show()

# %% [markdown]
# ### RobustScaler K-S Test

# %%
import numpy as np
from scipy.stats import kstest

def ks_test(df_name):
    ks_columns = []
    ks_columns.append([col for col in df_name])
    for i in ks_columns:
        for j in i:
            ks_test = kstest(df_name[j], 'norm')
            print(j, "의 pvalue:", ks_test.pvalue)

# %%
ks_test(scaled_df_part7)
# Out:
# 총자본증가율 의 pvalue: 1.5891298863865103e-154
# 순이익증가율 의 pvalue: 1.8773607304160735e-58
# 자기자본증가율 의 pvalue: 9.333159845623573e-122
# 매출액증가율 의 pvalue: 6.758713839850502e-63
# 종업원수증가율 의 pvalue: 1.8674445480235042e-101
# 정상영업손익증가율 의 pvalue: 6.663244377217723e-49
# 매출액정상영업이익률 의 pvalue: 6.933523569952399e-154
# 매출액순이익률 의 pvalue: 7.042296525723473e-123
# 총자본순이익률 의 pvalue: 1.2667025264360527e-87
# 총자본정상영업이익률 의 pvalue: 2.8861074256722565e-124
# 자기자본정상영업이익률 의 pvalue: 6.643670426092237e-119
# 자기자본순이익률 의 pvalue: 3.5078895735334474e-58
# 금융비용부담률 의 pvalue: 7.438599450013025e-104
# 수지비율 의 pvalue: 1.8239832014794044e-131
# 사내유보 대 자기자본비율 의 pvalue: 6.4217806135303044e-298
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 9.809736222195994e-252
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 1.3726136538159858e-268
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 7.446602823234902e-50
# CASH FLOW 대 매출액비율 의 pvalue: 1.0960013988711112e-110
# 재고자산대순운전자본비율 의 pvalue: 5.522323935602221e-114
# 총자본투자효율 의 pvalue: 4.6379174751383316e-108
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# 부가가치율 의 pvalue: 3.707467598369226e-157
# 노동소득분배율 의 pvalue: 1.3070573703083046e-53
# 종업원1인당부가가치율_계산 의 pvalue: 8.145594669810052e-231
# 노동장비율_계산 의 pvalue: 0.0
# 기계장비율_계산 의 pvalue: 0.0
# 자본집약도_계산 의 pvalue: 0.0
# 총자본회전률 의 pvalue: 4.829554300046973e-239
# 자기자본회전률 의 pvalue: 0.0
# 타인자본회전률 의 pvalue: 0.0
# 유동자산회전률 의 pvalue: 7.582566839817294e-255
# 당좌자산회전률 의 pvalue: 1.8133321e-316
# 재고자산회전률 의 pvalue: 0.0
# 매출채권회전률 의 pvalue: 0.0
# 순운전자본회전률 의 pvalue: 1.6458934851855456e-129

# %% [markdown]
# ### RobustScaler Shapiro–Wilk test

# %%
# pvalue 함수

from scipy import stats
from scipy.stats import shapiro

# 등락률 컬럼만 추출해서 pvalue 구하는 함수
def shap_pct(df_name):
    pct_columns = []
    pct_columns.append([col for col in df_name])
    for i in pct_columns:
        for j in i:
            shapiro_test = shapiro(df_name[j])
            print(j, "의 pvalue:", shapiro_test.pvalue)

# %%
# 컬럼별 pvalue 값 출력
shap_pct(scaled_df_part7)
# Out:
# 총자본증가율 의 pvalue: 0.0
# 순이익증가율 의 pvalue: 0.0
# 자기자본증가율 의 pvalue: 0.0
# 매출액증가율 의 pvalue: 0.0
# 종업원수증가율 의 pvalue: 0.0
# 정상영업손익증가율 의 pvalue: 0.0
# 매출액정상영업이익률 의 pvalue: 0.0
# 매출액순이익률 의 pvalue: 0.0
# 총자본순이익률 의 pvalue: 0.0
# 총자본정상영업이익률 의 pvalue: 4.203895392974451e-45
# 자기자본정상영업이익률 의 pvalue: 0.0
# 자기자본순이익률 의 pvalue: 0.0
# 금융비용부담률 의 pvalue: 0.0
# 수지비율 의 pvalue: 0.0
# 사내유보 대 자기자본비율 의 pvalue: 0.0
# 1주당매출액 의 pvalue: 0.0
# 1주당순이익 의 pvalue: 0.0
# 1주당 CASH FLOW 의 pvalue: 0.0
# 1주당순자산 의 pvalue: 0.0
# 유보율 의 pvalue: 0.0
# 자기자본구성비율 의 pvalue: 1.401298464324817e-44
# 유동비율 의 pvalue: 0.0
# 당좌비율 의 pvalue: 0.0
# 현금비율 의 pvalue: 0.0
# 매출채권 대 매입채무비율 의 pvalue: 0.0
# 부채비율 의 pvalue: 0.0
# 이자보상배율 의 pvalue: 0.0
# CASH FLOW 대 부채비율 의 pvalue: 0.0
# CASH FLOW 대 차입금비율 의 pvalue: 0.0
# CASH FLOW 대 총자본비율 의 pvalue: 1.3080256024650684e-30
# CASH FLOW 대 매출액비율 의 pvalue: 1.2751816025355835e-43
# 재고자산대순운전자본비율 의 pvalue: 0.0
# 총자본투자효율 의 pvalue: 1.2387478424631383e-42
# 설비투자효율 의 pvalue: 0.0
# 기계투자효율 의 pvalue: 0.0
# 부가가치율 의 pvalue: 0.0
# 노동소득분배율 의 pvalue: 0.0
# 종업원1인당부가가치율_계산 의 pvalue: 0.0
# 노동장비율_계산 의 pvalue: 0.0
# 기계장비율_계산 의 pvalue: 0.0
# 자본집약도_계산 의 pvalue: 0.0
# 총자본회전률 의 pvalue: 0.0
# 자기자본회전률 의 pvalue: 0.0
# 타인자본회전률 의 pvalue: 0.0
# 유동자산회전률 의 pvalue: 0.0
# 당좌자산회전률 의 pvalue: 0.0
# 재고자산회전률 의 pvalue: 0.0
# 매출채권회전률 의 pvalue: 0.0
# 순운전자본회전률 의 pvalue: 0.0

# %% [markdown]
# ## Logit T 검정

# %%
rb_df = pd.DataFrame()
rb_df = df_part7.iloc[:, :10]
rb_df[scaled_df_part7.columns.tolist()] = scaled_df_part7[scaled_df_part7.columns.tolist()]
rb_df
# Out:
#            회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0     (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1     (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2     (주)CMG제약  58820  201712  200108      NaN      0      0     0       제조업
# 3     (주)CMG제약  58820  201812  200108      NaN      0      0     0       제조업
# 4     (주)CMG제약  58820  201912  200108      NaN      0      0     0       제조업
# ...        ...    ...     ...     ...      ...    ...    ...   ...       ...
# 6609   흥구석유(주)  24060  201812  199412      NaN      0      0     0  도매 및 소매업
# 6610   흥구석유(주)  24060  201912  199412      NaN      0      0     0  도매 및 소매업
# 6611   흥아해운(주)   3280  201112  197606      NaN      0      0     0  운수 및 창고업
# 6612   흥아해운(주)   3280  201212  197606      NaN      0      0     0  운수 및 창고업
# 6613   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#       경기민감도    총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  \
# 0         1  0.398063  0.748807 -0.024544  2.342739  0.260207  13.934416
# 1         1  5.637333 -2.897275  4.577010 -0.648661 -0.195896  -8.290823
# 2         1 -0.390089  0.608673 -0.573751  0.939178  1.982230  -0.076414
# 3         1 -0.080933  1.039741  0.037603  0.665655  0.797546   0.745136
# 4         1  3.395301 -0.374550  4.451290  0.550760  0.591073   0.048379
# ...     ...       ...       ...       ...       ...       ...        ...
# 6609      1 -0.642145  0.182665 -0.303048  0.057546 -0.952401   0.531976
# 6610      1  0.293106  2.215192  0.244595 -0.691129 -0.636768  -0.562704
# 6611      0 -2.074526 -2.147982 -3.564064 -1.067958 -0.371906  -1.227428
# 6612      0 -0.293635  2.051927  0.294609  0.024645  0.186588   1.315464
# 6613      0 -0.944656 -2.779917 -2.951656 -0.233726 -0.321980  -3.510331
#
#       매출액정상영업이익률   매출액순이익률   총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  자기자본순이익률  \
# 0      -0.152188 -1.591153 -1.367601   -0.285290    -0.357484 -1.297020
# 1      -3.890932 -5.943700 -2.956386   -2.117385    -1.986465 -3.025140
# 2      -0.134432  0.463807 -0.098131   -0.427935    -0.511943 -0.260708
# 3       0.043120  1.178284  0.345794   -0.297177    -0.434713  0.033520
# 4      -0.046925  0.245308 -0.188474   -0.384844    -0.491242 -0.325885
# ...          ...       ...       ...         ...          ...       ...
# 6609   -0.526316 -0.260054 -0.021807   -0.427935    -0.512739 -0.211359
# 6610   -0.568167  0.285523  1.127726   -0.543834    -0.582803  0.521415
# 6611   -0.711477 -0.847185 -1.082555   -0.787519    -0.985669 -2.030726
# 6612   -0.034242 -0.167560 -0.046729    0.282318     1.569268  0.680633
# 6613   -0.809131 -1.630027 -1.764798   -0.852897    -1.311306 -4.950652
#
#        금융비용부담률      수지비율  사내유보 대 자기자본비율    1주당매출액    1주당순이익  1주당 CASH FLOW  \
# 0     0.292208  1.460840      -5.318817 -0.408475 -0.320483      -0.325586
# 1     1.415584  5.115778      -3.810845 -0.415006 -0.372018      -0.307061
# 2    -1.993506 -0.246311      -0.758783 -0.409488 -0.273452      -0.284849
# 3    -0.883117 -0.297389      -0.651742 -0.406367 -0.250412      -0.290040
# 4    -1.435065 -0.202043      -0.640643 -0.407831 -0.276611      -0.283551
# ...        ...       ...            ...       ...       ...            ...
# 6609 -0.233766  0.309875       0.168650  0.027041 -0.170969      -0.115327
# 6610 -0.305195 -0.249716       0.255373 -0.015227  0.135719      -0.268427
# 6611  0.961039  0.800227      -0.218314 -0.030203 -0.515593      -0.337903
# 6612  0.993506  0.216799      -0.276443 -0.005872 -0.124334      -0.091340
# 6613  2.155844  1.211124      -0.171660 -0.157838 -0.740657      -0.323117
#
#         1주당순자산       유보율  자기자본구성비율      유동비율      당좌비율      현금비율  \
# 0    -0.526825 -0.696197  0.242806  0.230828  0.300405 -0.192736
# 1    -0.521602 -0.687063 -0.089527  3.110809  3.654023  0.930024
# 2    -0.484986 -0.628528  0.965855  3.419495  3.817779  0.221165
# 3    -0.480162 -0.620820  1.012881  4.656697  5.085232  2.804912
# 4    -0.450393 -0.573253  1.099748  8.517235  9.676360  3.663026
# ...        ...       ...       ...       ...       ...       ...
# 6609 -0.154660  2.542373  1.098277  0.980470  1.165243  1.700549
# 6610 -0.116616  2.846317  1.047876  1.893957  2.082708  0.531591
# 6611 -0.432811 -0.525659 -1.142194 -0.578633 -0.461879 -0.404703
# 6612 -0.423954 -0.503235 -1.079232 -0.625121 -0.503717 -0.323805
# 6613 -0.489934 -0.623433 -1.376465 -0.735228 -0.636285 -0.379409
#
#       매출채권 대 매입채무비율      부채비율    이자보상배율  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0          1.816352 -0.196555 -0.075922         -2.325436          -2.935918
# 1          0.564810  0.092421 -0.452361         -0.793830          -0.450507
# 2          0.080796 -0.585728  1.477748          0.447021          -0.267394
# 3          0.974242 -0.604134  1.477748          0.082468          -0.267394
# 4          1.217191 -0.636516  9.918071          0.151830           9.758765
# ...             ...       ...       ...               ...                ...
# 6609     625.522202 -0.636024  0.228767          2.327049          -0.267394
# 6610     238.633243 -0.617421  8.216753          1.280976          -0.267394
# 6611      -0.592677  2.927264 -0.204739         -0.340155          -0.187060
# 6612      -0.575938  2.525787 -0.131654         -0.362738          -0.204396
# 6613      -0.594786  5.462008 -0.207742         -0.490170          -0.291077
#
#       CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  재고자산대순운전자본비율   총자본투자효율    설비투자효율  \
# 0             -2.820442          -3.181009      0.269460 -0.408208 -0.353712
# 1             -1.158840          -1.955220     -0.011609 -1.297984 -0.730997
# 2             -0.327348           0.100351      0.027251 -0.423461  0.207123
# 3             -0.487569          -0.277313      0.032485 -0.262212  0.451781
# 4             -0.526243          -0.242784     -0.020808 -0.613038  0.547332
# ...                 ...                ...           ...       ...       ...
# 6609          -0.052486          -0.369032     -0.473251 -0.620301 -0.540237
# 6610          -0.182320          -0.376585     -0.707398 -0.023243 -0.272121
# 6611          -0.316298          -0.376585     -0.290058 -0.829490 -0.596195
# 6612          -0.385359          -0.426221     -0.212262 -0.225894 -0.377171
# 6613          -0.726519          -0.637712     -0.180112 -0.937716 -0.668517
#
#             기계투자효율     부가가치율    노동소득분배율  종업원1인당부가가치율_계산  노동장비율_계산  기계장비율_계산  \
# 0    -1.496949e-01 -0.105859   1.138389       -0.777631 -0.352731  0.134402
# 1    -2.750150e-01 -1.070168  55.085349       -1.070866 -0.364556  0.109951
# 2     1.274151e-01  0.618721   0.428649       -0.341830 -0.305760  0.060446
# 3     2.229472e-01  0.660741   0.407434       -0.264507 -0.321365  0.033442
# 4     1.794935e-01  0.589630   0.564792       -0.232001 -0.210116  0.019918
# ...            ...       ...        ...             ...       ...       ...
# 6609  2.972235e+00 -0.920404  -0.237817       -0.139260  1.530355 -0.222754
# 6610  3.424330e+00 -0.620875  -1.059264        0.945904  1.505278 -0.167576
# 6611  8.379611e+02 -0.870303   0.919684       -0.625070  1.076781 -0.283473
# 6612  3.375601e+03 -0.556768  -0.303774       -0.026264  0.943585 -0.283473
# 6613  1.633225e+06 -0.862761   2.482754       -0.592243  2.311904 -0.283473
#
#       자본집약도_계산    총자본회전률   자기자본회전률    타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률  \
# 0    -0.593803 -0.379310 -0.335346  -0.155251 -0.449612 -0.460784 -0.162807
# 1    -0.320473 -0.844828 -0.560546  -0.648402 -1.015504 -0.941176 -0.229240
# 2    -0.169059 -0.862069 -0.723216   0.689498 -1.015504 -0.941176 -0.219883
# 3    -0.209356 -0.741379 -0.670845   0.995434 -0.945736 -0.887255 -0.197427
# 4     0.139637 -0.862069 -0.726433   1.305936 -1.023256 -0.950980 -0.141287
# ...        ...       ...       ...        ...       ...       ...       ...
# 6609  0.260251  2.172414  0.522767   9.100457  7.658915  5.524510  6.567485
# 6610  0.462496  1.758621  0.613289  10.972603  5.232558  3.588235  5.637427
# 6611  0.084003  0.672414 -0.005370  -0.319635  2.310078  1.382353  4.000000
# 6612  0.044643  0.827586  3.124629  -0.269406  3.093023  2.004902  3.944795
# 6613  0.273032  0.086207  2.104169  -0.561644  4.534884  3.338235  3.361871
#
#        매출채권회전률   순운전자본회전률
# 0    -0.784969  -0.406250
# 1    -0.910230  -1.093750
# 2    -0.668058  -1.031250
# 3    -0.653445  -0.890625
# 4    -0.645094  -1.015625
# ...        ...        ...
# 6609  5.177453  10.875000
# 6610  5.281837   9.046875
# 6611  4.430063   1.453125
# 6612  4.290188   1.609375
# 6613  3.521921   1.515625
#
# [6614 rows x 59 columns]

# %%
# 로짓모듈가져와서 진행 
import statsmodels.api as sm

# 피처값만 데이터프레임에 불러오기
df_rb_sig_copy = rb_df.copy() 
x = df_rb_sig_copy.iloc[:, 10:]

#  상수항 추가
x = sm.add_constant(x, has_constant = "add")
log_reg = sm.Logit(df_rb_sig_copy['부실기업1'], x).fit()
print(log_reg.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.152696
#          Iterations 11
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                  부실기업1   No. Observations:                 6614
# Model:                          Logit   Df Residuals:                     6564
# Method:                           MLE   Df Model:                           49
# Date:                Thu, 06 Oct 2022   Pseudo R-squ.:                  0.2775
# Time:                        16:04:18   Log-Likelihood:                -1009.9
# converged:                       True   LL-Null:                       -1397.9
# Covariance Type:            nonrobust   LLR p-value:                1.831e-131
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -3.3997      0.100    -34.084      0.000      -3.595      -3.204
# 총자본증가율               -0.0660      0.040     -1.664      0.096      -0.144       0.012
# 순이익증가율                0.0013      0.001      1.379      0.168      -0.001       0.003
# 자기자본증가율              -0.0008      0.003     -0.282      0.778      -0.006       0.005
# 매출액증가율                0.0246      0.010      2.354      0.019       0.004       0.045
# 종업원수증가율              -0.0494      0.030     -1.625      0.104      -0.109       0.010
# 정상영업손익증가율            -0.0063      0.003     -2.093      0.036      -0.012      -0.000
# 매출액정상영업이익률            0.2213      0.069      3.198      0.001       0.086       0.357
# 매출액순이익률              -0.0644      0.051     -1.266      0.205      -0.164       0.035
# 총자본순이익률               0.1421      0.113      1.260      0.208      -0.079       0.363
# 총자본정상영업이익률           -0.9092      0.174     -5.237      0.000      -1.250      -0.569
# 자기자본정상영업이익률          -0.0992      0.069     -1.436      0.151      -0.235       0.036
# 자기자본순이익률              0.0013      0.009      0.152      0.879      -0.015       0.018
# 금융비용부담률               0.1088      0.030      3.635      0.000       0.050       0.167
# 수지비율                  0.0019      0.039      0.049      0.961      -0.075       0.079
# 사내유보 대 자기자본비율         0.0026      0.007      0.351      0.725      -0.012       0.017
# 1주당매출액                0.0485      0.046      1.051      0.293      -0.042       0.139
# 1주당순이익               -0.0830      0.033     -2.538      0.011      -0.147      -0.019
# 1주당 CASH FLOW        -0.0339      0.026     -1.283      0.199      -0.086       0.018
# 1주당순자산               -0.1169      0.070     -1.664      0.096      -0.255       0.021
# 유보율                  -0.2945      0.122     -2.410      0.016      -0.534      -0.055
# 자기자본구성비율              0.1605      0.077      2.079      0.038       0.009       0.312
# 유동비율                 -1.1425      0.393     -2.909      0.004      -1.912      -0.373
# 당좌비율                  1.0277      0.346      2.966      0.003       0.349       1.707
# 현금비율                 -0.0181      0.058     -0.310      0.757      -0.132       0.096
# 매출채권 대 매입채무비율        -0.0005      0.004     -0.128      0.898      -0.008       0.007
# 부채비율               2.973e-05      0.009      0.003      0.997      -0.018       0.018
# 이자보상배율            -2.645e-05    9.6e-06     -2.756      0.006   -4.53e-05   -7.64e-06
# CASH FLOW 대 부채비율     -0.1900      0.091     -2.083      0.037      -0.369      -0.011
# CASH FLOW 대 차입금비율 -5.949e-05      0.001     -0.100      0.921      -0.001       0.001
# CASH FLOW 대 총자본비율    -0.2079      0.098     -2.128      0.033      -0.399      -0.016
# CASH FLOW 대 매출액비율     0.0308      0.017      1.808      0.071      -0.003       0.064
# 재고자산대순운전자본비율         -0.0028      0.002     -1.477      0.140      -0.006       0.001
# 총자본투자효율               0.0252      0.105      0.240      0.810      -0.180       0.231
# 설비투자효율               -0.0012      0.003     -0.415      0.678      -0.007       0.005
# 기계투자효율             5.665e-08   2.61e-07      0.217      0.828   -4.55e-07    5.69e-07
# 부가가치율                 0.0445      0.105      0.426      0.670      -0.160       0.249
# 노동소득분배율               0.0004      0.000      1.235      0.217      -0.000       0.001
# 종업원1인당부가가치율_계산        0.0168      0.030      0.551      0.582      -0.043       0.077
# 노동장비율_계산              0.0451      0.039      1.160      0.246      -0.031       0.121
# 기계장비율_계산              0.0144      0.028      0.517      0.605      -0.040       0.069
# 자본집약도_계산             -0.0358      0.026     -1.367      0.172      -0.087       0.016
# 총자본회전률                0.0040      0.183      0.022      0.983      -0.355       0.363
# 자기자본회전률              -0.0032      0.015     -0.218      0.827      -0.032       0.026
# 타인자본회전률              -0.2098      0.204     -1.029      0.303      -0.609       0.190
# 유동자산회전률               0.1424      0.218      0.652      0.514      -0.285       0.570
# 당좌자산회전률               0.2715      0.162      1.672      0.094      -0.047       0.590
# 재고자산회전률              -0.0028      0.002     -1.186      0.236      -0.007       0.002
# 매출채권회전률           -5.339e-05      0.000     -0.154      0.878      -0.001       0.001
# 순운전자본회전률             -0.5173      0.257     -2.011      0.044      -1.021      -0.013
# =====================================================================================

# %%
#로짓분석상 유의한 변수만을 추출
p_value = pd.DataFrame(log_reg.pvalues)
print(p_value[p_value[0] < 0.05], '\n유의한 변수의 수 :' ,len(p_value[p_value[0] < 0.05]))
# Out:
#                                0
# const              1.272028e-254
# 매출액증가율              1.857704e-02
# 정상영업손익증가율           3.638169e-02
# 매출액정상영업이익률          1.384214e-03
# 총자본정상영업이익률          1.632583e-07
# 금융비용부담률             2.781074e-04
# 1주당순이익              1.114821e-02
# 유보율                 1.594100e-02
# 자기자본구성비율            3.766152e-02
# 유동비율                3.626139e-03
# 당좌비율                3.017508e-03
# 이자보상배율              5.842640e-03
# CASH FLOW 대 부채비율    3.724123e-02
# CASH FLOW 대 총자본비율   3.335318e-02
# 순운전자본회전률            4.428317e-02
# 유의한 변수의 수 : 15

# %%
# 4-1) VIF

import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

def feature_engineering_XbyVIF(df_cols):
    vif = pd.DataFrame()
    vif['VIF_Factor'] = [variance_inflation_factor(df_cols.values, i)
                        for i in range(df_cols.shape[1])]
    vif['Feature'] = df_cols.columns
    return vif

# %%
# 4-2) VIf 데이터프레임 확인
feature_vif = feature_engineering_XbyVIF(rb_df.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#     VIF_Factor            Feature
# 0    47.692555               유동비율
# 1    44.210441               당좌비율
# 2    18.334605         매출액정상영업이익률
# 3    13.315536              부가가치율
# 4    13.175413            유동자산회전률
# 5    11.397932           순운전자본회전률
# 6    10.144116               수지비율
# 7     8.532000         총자본정상영업이익률
# 8     7.478352  CASH FLOW 대 매출액비율
# 9     6.485585            당좌자산회전률
# 10    5.399416        자기자본정상영업이익률
# 11    5.084731             1주당순자산
# 12    5.067458            타인자본회전률
# 13    4.873086             1주당매출액
# 14    4.576816            총자본순이익률
# 15    4.476114             총자본회전률
# 16    3.829555               부채비율
# 17    3.669639            자기자본회전률
# 18    3.465079   CASH FLOW 대 부채비율
# 19    3.407774            총자본투자효율
# 20    3.251851      1주당 CASH FLOW
# 21    3.032083  CASH FLOW 대 총자본비율
# 22    2.698478             1주당순이익
# 23    2.474431           자기자본구성비율
# 24    2.463141               현금비율
# 25    2.274646     종업원1인당부가가치율_계산
# 26    2.198611            매출액순이익률
# 27    2.052718           자본집약도_계산
# 28    1.746000                유보율
# 29    1.683645           노동장비율_계산
# 30    1.506396           자기자본순이익률
# 31    1.503385           기계장비율_계산
# 32    1.433375            금융비용부담률
# 33    1.234798             총자본증가율
# 34    1.169118      사내유보 대 자기자본비율
# 35    1.155102             매출액증가율
# 36    1.036212            재고자산회전률
# 37    1.031169          정상영업손익증가율
# 38    1.024462            종업원수증가율
# 39    1.020293      매출채권 대 매입채무비율
# 40    1.018751       재고자산대순운전자본비율
# 41    1.013699             설비투자효율
# 42    1.009144  CASH FLOW 대 차입금비율
# 43    1.005961            매출채권회전률
# 44    1.005179             이자보상배율
# 45    1.003255            자기자본증가율
# 46    1.002712            노동소득분배율
# 47    1.002375             기계투자효율
# 48    1.001700             순이익증가율

# %%
wins_vif = rb_df.drop(['부가가치율',
'유동자산회전률',
'수지비율'
],axis=1)

# %%
# 4-2) VIf 데이터프레임 재확인
feature_vif = feature_engineering_XbyVIF(wins_vif.iloc[:, 10:])
feature_vif_df = pd.DataFrame(feature_vif)
feature_vif_df.sort_values('VIF_Factor', ascending=False).reset_index(drop=True)
# Out:
#     VIF_Factor            Feature
# 0    42.458265               유동비율
# 1    38.561628               당좌비율
# 2     8.013242         총자본정상영업이익률
# 3     7.121504  CASH FLOW 대 매출액비율
# 4     6.855647           순운전자본회전률
# 5     6.371609         매출액정상영업이익률
# 6     5.373922        자기자본정상영업이익률
# 7     5.081151             1주당순자산
# 8     4.889955            타인자본회전률
# 9     4.872655             1주당매출액
# 10    4.086763            총자본순이익률
# 11    3.927910             총자본회전률
# 12    3.826665               부채비율
# 13    3.666524            자기자본회전률
# 14    3.455182            당좌자산회전률
# 15    3.388405   CASH FLOW 대 부채비율
# 16    3.247727      1주당 CASH FLOW
# 17    2.990524  CASH FLOW 대 총자본비율
# 18    2.683097             1주당순이익
# 19    2.458083               현금비율
# 20    2.312172           자기자본구성비율
# 21    2.194549            매출액순이익률
# 22    2.020335     종업원1인당부가가치율_계산
# 23    1.917515           자본집약도_계산
# 24    1.862157            총자본투자효율
# 25    1.738485                유보율
# 26    1.648325           노동장비율_계산
# 27    1.506020           자기자본순이익률
# 28    1.498763           기계장비율_계산
# 29    1.337722            금융비용부담률
# 30    1.215317             총자본증가율
# 31    1.164162      사내유보 대 자기자본비율
# 32    1.154941             매출액증가율
# 33    1.034786            재고자산회전률
# 34    1.031127          정상영업손익증가율
# 35    1.023494            종업원수증가율
# 36    1.019925      매출채권 대 매입채무비율
# 37    1.018566       재고자산대순운전자본비율
# 38    1.012653             설비투자효율
# 39    1.009007  CASH FLOW 대 차입금비율
# 40    1.005839            매출채권회전률
# 41    1.004884             이자보상배율
# 42    1.003254            자기자본증가율
# 43    1.002611            노동소득분배율
# 44    1.002195             기계투자효율
# 45    1.001440             순이익증가율

# %%
# 재무비율이 아닌 컬럼
no_finan_list = df_part7.columns[:10].tolist()

# %%
# 유의한 컬럼
feature_vif_list = feature_vif_df['Feature'].tolist()

# %%
logit_vif = pd.DataFrame()
logit_vif[no_finan_list] = df_part7[no_finan_list]
logit_vif[feature_vif_list] = df_part7[feature_vif_list]
logit_vif.to_csv('../data/유의성/brok1_dataset1_raw_rb_logit_vif.csv', index=False, encoding='CP949')

# %%
logit_vif
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        경기민감도      총자본증가율       순이익증가율    자기자본증가율     매출액증가율  종업원수증가율  \
# 0          1   13.166482    80.280163   5.219839  56.396905     4.65
# 1          1  109.147119  -341.571868  75.170505  -8.429134    -0.74
# 2          1   -2.093352  2348.675303  55.100407  25.510008     1.49
# 3          1    3.855597   -46.641074   0.010946  11.520576    20.59
# 4          1   -2.644307 -2409.614083  -4.480893  18.851969    -4.88
# ...      ...         ...          ...        ...        ...      ...
# 12738      0    7.026008    17.748954  24.611435   5.977506    -3.78
# 12739      0   13.690307     1.063296   7.760601   7.171915     9.90
# 12740      0   21.933460   -42.676587   3.389326   2.420227     7.68
# 12741      0   21.081715  -263.287062  11.215038  -1.581947    15.87
# 12742      0  -11.431409  -327.993526 -39.276758   0.562842    -2.23
#
#          정상영업손익증가율  매출액정상영업이익률  매출액순이익률  총자본순이익률  총자본정상영업이익률  자기자본정상영업이익률  \
# 0      1263.950784        3.61    -8.50    -5.58        2.37         3.51
# 1      -756.819406      -25.87   -40.97   -15.78       -9.96       -16.95
# 2       631.501169        3.88     1.45     0.52        1.40         1.96
# 3       -44.098325        1.94     0.69     0.28        0.78         0.90
# 4      -681.514824       -9.51   -13.50    -6.37       -4.49        -5.37
# ...            ...         ...      ...      ...         ...          ...
# 12738   -41.383093        2.51     2.36     3.29        3.50        13.80
# 12739    -3.906495        2.25     2.22     3.01        3.04        11.51
# 12740    14.408829        2.51     1.24     1.46        2.95        12.48
# 12741   -72.247242        0.71    -2.06    -1.96        0.67         3.23
# 12742  -322.165979       -1.57    -8.79    -8.13       -1.45        -8.47
#
#        자기자본순이익률  금융비용부담률    수지비율  사내유보 대 자기자본비율       1주당매출액      1주당순이익  \
# 0         -8.28     0.80  108.35        -245.87   406.280703  -34.519834
# 1        -26.84     2.53  140.55        -165.71   246.198501 -100.872314
# 2          0.74     1.65   98.55        -106.33   235.517466    3.419043
# 3          0.32    -0.65   99.32        -106.65   262.650435    1.824365
# 4         -7.62    -0.11  113.24        -120.22   306.259774  -41.338674
# ...         ...      ...     ...            ...          ...         ...
# 12738     12.97     1.84   95.90          18.35  9088.600308  214.300424
# 12739     11.37     1.66   97.18          16.84  9740.426978  216.579071
# 12740      6.18     2.22   98.11          11.64  9976.167403  124.150515
# 12741     -9.40     3.21  100.55           6.97  6512.596843 -134.467088
# 12742    -47.52     3.67  106.15          27.74  6549.252463 -575.510430
#
#        1주당 CASH FLOW       1주당순자산     유보율   자기자본구성비율    유동비율    당좌비율    현금비율  \
# 0         -58.600377   418.623493  -17.45  66.046945  200.97  165.03   15.10
# 1         -23.817768   478.648111   -4.31  55.317408  693.49  649.98   68.81
# 2         -45.471032   566.198482   13.12  87.631971  694.71  610.74  394.63
# 3           8.367993   566.417813   13.13  84.387905  324.58  268.23  101.24
# 4          27.296492   530.854621    6.02  82.795953  296.85  235.21   29.00
# ...              ...          ...     ...        ...     ...     ...     ...
# 12738     317.421335  1664.376003  273.07  27.203257   71.73   65.91   12.19
# 12739       5.153858  1817.138085  301.53  25.784426   65.25   59.64    8.09
# 12740     400.330868  1910.263815  314.93  21.863026   51.92   47.54    7.76
# 12741     -10.880790  1439.386602  205.62  20.081457   39.46   32.52    5.46
# 12742     -53.965366   842.628688   87.23  13.767987   35.76   29.58    6.17
#
#        매출채권 대 매입채무비율    부채비율  이자보상배율  CASH FLOW 대 부채비율  CASH FLOW 대 차입금비율  \
# 0             602.31   51.41    3.53            -46.08            -172.40
# 1             323.41   80.77   -7.75             -8.10             -11.83
# 2             282.72   14.11    0.70            -39.85            -194.73
# 3             285.31   18.50    3.60            -17.73            -104.12
# 4             254.69   20.78  -32.22             16.12           24988.82
# ...              ...     ...     ...               ...                ...
# 12738          64.64  267.60    1.15              6.48              10.54
# 12739          66.36  287.83    1.12              2.84               5.73
# 12740          60.44  357.39    1.02              2.78               6.61
# 12741          68.73  397.97    0.21              2.12               6.30
# 12742          65.00  626.32   -0.42             -0.57              -1.53
#
#        CASH FLOW 대 총자본비율  CASH FLOW 대 매출액비율  재고자산대순운전자본비율  총자본투자효율  설비투자효율  \
# 0                 -15.65             -24.07     35.590076    12.72   35.86
# 1                  -3.62             -12.71      7.330001     0.47    2.89
# 2                  -4.93             -13.51     14.120364    12.51   77.91
# 3                  -2.77              -7.06     25.090228    12.16   37.80
# 4                   2.77               5.80     31.315211     7.63   24.21
# ...                  ...                ...           ...      ...     ...
# 12738               4.71               3.50    -20.576399    14.13   36.63
# 12739               2.10               1.66    -16.142234    13.89   27.88
# 12740               2.17               2.03     -9.102981    13.11   21.49
# 12741               1.70               1.96    -11.471676    10.98   15.81
# 12742              -0.49              -0.50     -9.612150     5.43    8.35
#
#              기계투자효율  부가가치율      노동소득분배율  종업원1인당부가가치율_계산    노동장비율_계산  \
# 0      1.285100e+02  19.56    89.819047       27.179630   71.503704
# 1      1.067000e+01   1.66  1749.845902       -0.657015   69.134328
# 2      2.894000e+02  34.29    71.284323       51.118235   79.448529
# 3      1.320600e+02  31.04    76.809811       43.079512  114.841463
# 4      9.092000e+01  15.96   134.474407       27.671795  114.243590
# ...             ...    ...          ...             ...         ...
# 12738  5.737466e+06  10.48    37.002209      103.399418  318.938865
# 12739  1.218393e+07  10.93    48.001879      102.744066  423.879470
# 12740  3.459744e+09  12.28    50.647901      108.702706  590.180812
# 12741  3.509713e+09  12.66    66.490562       86.464501  709.037155
# 12742  1.535742e+09   5.51   131.187104       44.778480  605.404995
#
#         기계장비율_계산     자본집약도_계산  총자본회전률   자기자본회전률  타인자본회전률  당좌자산회전률  재고자산회전률  \
# 0      19.715837   204.066667    0.66  0.984333     2.01     1.55     6.42
# 1      18.562172   425.291045    0.39  0.655130     0.93     0.57     5.71
# 2      17.604882   411.485294    0.36  0.506332     1.26     0.52     5.39
# 3      30.445768   354.432927    0.40  0.464339     2.85     0.80     4.77
# 4      28.007199   362.769231    0.47  0.564493     2.88     1.22     5.22
# ...          ...          ...     ...       ...      ...      ...      ...
# 12738   0.000000   795.036390    1.39  6.107006     1.87     5.70    56.65
# 12739   0.000000   831.529801    1.35  5.499239     1.84     5.44    59.77
# 12740   0.000000   948.600246    1.17  5.113218     1.54     6.38    68.48
# 12741   0.000000  1000.623142    0.95  4.964267     1.20     7.96    56.47
# 12742   0.000000   905.653637    0.93  4.550483     1.12     9.30    44.09
#
#        매출채권회전률  순운전자본회전률
# 0         2.45      0.86
# 1         1.85      0.42
# 2         2.07      0.42
# 3         1.86      0.56
# 4         2.10      0.75
# ...        ...       ...
# 12738    27.46      2.02
# 12739    26.03      2.03
# 12740    25.33      2.15
# 12741    25.24      2.19
# 12742    23.08      2.09
#
# [12743 rows x 58 columns]

# %% [markdown]
# ### RobustScaler 등분산, 이분산 확인

# %% [markdown]
# ## Bartlett

# %%
scaled_df_part7['부실기업'] = df_part7.iloc[:, 7]
scaled_df_part7.head(5)
# Out:
#      총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  매출액정상영업이익률  \
# 0  0.038129 -0.006213 -0.026901  0.177793  0.001221   0.492988    0.002422
# 1  2.405612 -0.014917  0.133131 -0.088548 -0.109675  -0.284790   -0.394514
# 2 -0.338274  0.040588  0.087215  0.050893 -0.063794   0.249564    0.006057
# 3 -0.191536 -0.008832 -0.038818 -0.006584  0.329179  -0.010469   -0.020064
# 4 -0.351864 -0.057584 -0.049094  0.023538 -0.194854  -0.255806   -0.174233
#
#     매출액순이익률   총자본순이익률  총자본정상영업이익률  ...  자본집약도_계산    총자본회전률   자기자본회전률  \
# 0 -0.096454 -0.868161   -0.322687  ... -0.186750 -0.573517 -0.173354
# 1 -0.379481 -1.901359   -1.938114  ... -0.166846 -1.083230 -0.230282
# 2 -0.009725 -0.250268   -0.449773  ... -0.168088 -1.139865 -0.256014
# 3 -0.016349 -0.274578   -0.531003  ... -0.173221 -1.064352 -0.263276
# 4 -0.140037 -0.948183   -1.221457  ... -0.172471 -0.932204 -0.245956
#
#     타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률   매출채권회전률  순운전자본회전률  부실기업
# 0 -0.422910 -0.670420 -0.685081 -0.035909 -0.020210 -0.575575     0
# 1 -0.933345 -1.275654 -1.194169 -0.035989 -0.020429 -1.311001     0
# 2 -0.777379 -1.308817 -1.220143 -0.036025 -0.020349 -1.311001     0
# 3 -0.025904 -1.143000 -1.074689 -0.036094 -0.020425 -1.077002     0
# 4 -0.011726 -0.885983 -0.856509 -0.036044 -0.020338 -0.759431     0
#
# [5 rows x 50 columns]

# %%
from scipy.stats import bartlett

homosced = []
heterosced = []

bart_df = scaled_df_part7.iloc[:, 10:]

nc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==0]  # normal company 
bc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==1]  # bankrupt company

bart_sced_df = pd.DataFrame(index=['등분산성'])

for i in bart_df.columns:
    bart_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    bartresult = np.round(bartlett(ser_1, ser_2)[1], 3)
    
    if bartresult < 0.05:
        homosced.append(i)
        bart_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", bartresult,"-> 등분산")
    else:
        heterosced.append(i)
        bart_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", bartresult,"-> 이분산")
        
    print("**********************************************************")
# Out:
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 금융비용부담률 pvalue 0.0 -> 등분산
# **********************************************************
# 수지비율 pvalue 0.0 -> 등분산
# **********************************************************
# 사내유보 대 자기자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당매출액 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순이익 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당 CASH FLOW pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순자산 pvalue 0.0 -> 등분산
# **********************************************************
# 유보율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본구성비율 pvalue 0.168 -> 이분산
# **********************************************************
# 유동비율 pvalue 0.052 -> 이분산
# **********************************************************
# 당좌비율 pvalue 0.036 -> 등분산
# **********************************************************
# 현금비율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출채권 대 매입채무비율 pvalue 0.0 -> 등분산
# **********************************************************
# 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# 이자보상배율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 차입금비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 총자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 매출액비율 pvalue 0.0 -> 등분산
# **********************************************************
# 재고자산대순운전자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 설비투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 기계투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 부가가치율 pvalue 0.0 -> 등분산
# **********************************************************
# 노동소득분배율 pvalue 0.0 -> 등분산
# **********************************************************
# 종업원1인당부가가치율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 노동장비율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 기계장비율_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 자본집약도_계산 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본회전률 pvalue 0.141 -> 이분산
# **********************************************************
# 자기자본회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 타인자본회전률 pvalue 0.542 -> 이분산
# **********************************************************
# 유동자산회전률 pvalue 0.043 -> 등분산
# **********************************************************
# 당좌자산회전률 pvalue 0.001 -> 등분산
# **********************************************************
# 재고자산회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 매출채권회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 순운전자본회전률 pvalue 0.446 -> 이분산
# **********************************************************
# 부실기업 pvalue nan -> 이분산
# **********************************************************
# c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:2468: RuntimeWarning: divide by zero encountered in log
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)
# c:\Users\wndgj\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\stats\_morestats.py:2468: RuntimeWarning: invalid value encountered in double_scalars
#   numer = (Ntot*1.0 - k) * log(spsq) - np.sum((Ni - 1.0)*log(ssq), axis=0)

# %%
# 피처별 등분산성 데이터프레임 생성
bart_sced_df = bart_sced_df.transpose()
bart_sced_df
# Out:
#                   등분산성
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           이분산
# 유동비율               이분산
# 당좌비율               등분산
# 현금비율               등분산
# 매출채권 대 매입채무비율      등분산
# 부채비율               등분산
# 이자보상배율             등분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  등분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       등분산
# 총자본투자효율            등분산
# 설비투자효율             등분산
# 기계투자효율             등분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     등분산
# 노동장비율_계산           등분산
# 기계장비율_계산           등분산
# 자본집약도_계산           등분산
# 총자본회전률             이분산
# 자기자본회전률            등분산
# 타인자본회전률            이분산
# 유동자산회전률            등분산
# 당좌자산회전률            등분산
# 재고자산회전률            등분산
# 매출채권회전률            등분산
# 순운전자본회전률           이분산
# 부실기업               이분산

# %%
bart_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     34
# 이분산      6
# dtype: int64

# %% [markdown]
# ### 이상치 제거 전 Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)

        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)

        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 금융비용부담률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 수지비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 사내유보 대 자기자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당매출액 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순이익 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당 CASH FLOW 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순자산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유보율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 당좌비율 의 pvalue: 0.417
# **********************************************************
# 등분산을 가정한 현금비율 의 pvalue: 0.634
# **********************************************************
# 등분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.619
# **********************************************************
# 등분산을 가정한 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 이자보상배율 의 pvalue: 0.097
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 차입금비율 의 pvalue: 0.51
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 총자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 매출액비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산대순운전자본비율 의 pvalue: 0.435
# **********************************************************
# 등분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 설비투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 기계투자효율 의 pvalue: 0.442
# **********************************************************
# 등분산을 가정한 부가가치율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동소득분배율 의 pvalue: 0.036
# **********************************************************
# 등분산을 가정한 종업원1인당부가가치율_계산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동장비율_계산 의 pvalue: 0.703
# **********************************************************
# 등분산을 가정한 기계장비율_계산 의 pvalue: 0.415
# **********************************************************
# 등분산을 가정한 자본집약도_계산 의 pvalue: 0.108
# **********************************************************
# 등분산을 가정한 자기자본회전률 의 pvalue: 0.733
# **********************************************************
# 등분산을 가정한 유동자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산회전률 의 pvalue: 0.009
# **********************************************************
# 등분산을 가정한 매출채권회전률 의 pvalue: 0.649
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  22 개
# ['자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '유동자산회전률', '당좌자산회전률', '재고자산회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

nc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 이분산성 Welch's T-test
def ttest_hetero(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)

        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
            
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 자기자본구성비율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 유동비율 의 pvalue: 0.14
# **********************************************************
# 이분산을 가정한 총자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 타인자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 순운전자본회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 부실기업 의 pvalue: 0.0
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  5 개
# ['자기자본구성비율', '총자본회전률', '타인자본회전률', '순운전자본회전률', '부실기업']

# %%
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처:  ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '종업원1인당부가가치율_계산', '유동자산회전률', '당좌자산회전률', '재고자산회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처:  ['자기자본구성비율', '총자본회전률', '타인자본회전률', '순운전자본회전률']

# %%
for i, col in enumerate(df_part7):
    print(i, col)
# Out:
# 0 회사명
# 1 거래소코드
# 2 회계년도
# 3 상장일
# 4 상장폐지일_x
# 5 부실기업1
# 6 부실기업2
# 7 부실기업
# 8 업종
# 9 경기민감도
# 10 총자본증가율
# 11 순이익증가율
# 12 자기자본증가율
# 13 매출액증가율
# 14 종업원수증가율
# 15 정상영업손익증가율
# 16 매출액정상영업이익률
# 17 매출액순이익률
# 18 총자본순이익률
# 19 총자본정상영업이익률
# 20 자기자본정상영업이익률
# 21 자기자본순이익률
# 22 금융비용부담률
# 23 수지비율
# 24 사내유보 대 자기자본비율
# 25 1주당매출액
# 26 1주당순이익
# 27 1주당 CASH FLOW
# 28 1주당순자산
# 29 유보율
# 30 자기자본구성비율
# 31 유동비율
# 32 당좌비율
# 33 현금비율
# 34 매출채권 대 매입채무비율
# 35 부채비율
# 36 이자보상배율
# 37 CASH FLOW 대 부채비율
# 38 CASH FLOW 대 차입금비율
# 39 CASH FLOW 대 총자본비율
# 40 CASH FLOW 대 매출액비율
# 41 재고자산대순운전자본비율
# 42 총자본투자효율
# 43 설비투자효율
# 44 기계투자효율
# 45 부가가치율
# 46 노동소득분배율
# 47 종업원1인당부가가치율_계산
# 48 노동장비율_계산
# 49 기계장비율_계산
# 50 자본집약도_계산
# 51 총자본회전률
# 52 자기자본회전률
# 53 타인자본회전률
# 54 유동자산회전률
# 55 당좌자산회전률
# 56 재고자산회전률
# 57 매출채권회전률
# 58 순운전자본회전률

# %%
df_ss_sig = pd.DataFrame()
df_ss_sig = df_part7.iloc[:, :10]
df_ss_sig[significant_homosced] = scaled_df_part7[significant_homosced]
df_ss_sig[significant_heterosced] = scaled_df_part7[significant_heterosced]

# %%
df_ss_sig
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
#        자기자본정상영업이익률  ...     부가가치율   노동소득분배율  종업원1인당부가가치율_계산   유동자산회전률  \
# 0        -0.291344  ... -0.080259  0.014457       -0.181412 -0.670420
# 1        -1.575307  ... -0.440954  0.915093       -0.217939 -1.275654
# 2        -0.388614  ...  0.216560  0.004401       -0.149999 -1.308817
# 3        -0.455134  ...  0.151070  0.007399       -0.160548 -1.143000
# 4        -0.848607  ... -0.152801  0.038685       -0.180766 -0.885983
# ...            ...  ...       ...       ...             ...       ...
# 12738     0.354402  ... -0.263226 -0.014198       -0.081396  2.587893
# 12739     0.210694  ... -0.254158 -0.008231       -0.082256  2.422076
# 12740     0.271566  ... -0.226955 -0.006795       -0.074437  3.126800
# 12741    -0.308916  ... -0.219298  0.001800       -0.103618  4.080250
# 12742    -1.043146  ... -0.363375  0.036901       -0.158318  4.660611
#
#         당좌자산회전률   재고자산회전률  자기자본구성비율    총자본회전률   타인자본회전률  순운전자본회전률
# 0     -0.685081 -0.035909  0.325597 -0.573517 -0.422910 -0.575575
# 1     -1.194169 -0.035989 -0.132178 -1.083230 -0.933345 -1.311001
# 2     -1.220143 -0.036025  1.246522 -1.139865 -0.777379 -1.311001
# 3     -1.074689 -0.036094  1.108114 -1.064352 -0.025904 -1.077002
# 4     -0.856509 -0.036044  1.040194 -0.932204 -0.011726 -0.759431
# ...         ...       ...       ...       ...       ...       ...
# 12738  1.470748 -0.030278 -1.331667  0.804597 -0.489077  1.363278
# 12739  1.335684 -0.029929 -1.392202  0.729084 -0.503256  1.379992
# 12740  1.823992 -0.028952 -1.559508  0.389275 -0.645044  1.580563
# 12741  2.644766 -0.030299 -1.635519 -0.026047 -0.805736  1.647420
# 12742  3.340865 -0.031686 -1.904883 -0.063804 -0.843547  1.480278
#
# [12743 rows x 35 columns]

# %%
df_ss_sig.to_csv('../data/유의성/rbscaler_data.csv', index=False, encoding='CP949')

# %% [markdown]
# ## Levene

# %%
scaled_df_part7['부실기업'] = df_part7.iloc[:, 7]
scaled_df_part7.head(5)
# Out:
#      총자본증가율    순이익증가율   자기자본증가율    매출액증가율   종업원수증가율  정상영업손익증가율  매출액정상영업이익률  \
# 0  0.038129 -0.006213 -0.026901  0.177793  0.001221   0.492988    0.002422
# 1  2.405612 -0.014917  0.133131 -0.088548 -0.109675  -0.284790   -0.394514
# 2 -0.338274  0.040588  0.087215  0.050893 -0.063794   0.249564    0.006057
# 3 -0.191536 -0.008832 -0.038818 -0.006584  0.329179  -0.010469   -0.020064
# 4 -0.351864 -0.057584 -0.049094  0.023538 -0.194854  -0.255806   -0.174233
#
#     매출액순이익률   총자본순이익률  총자본정상영업이익률  ...  자본집약도_계산    총자본회전률   자기자본회전률  \
# 0 -0.096454 -0.868161   -0.322687  ... -0.186750 -0.573517 -0.173354
# 1 -0.379481 -1.901359   -1.938114  ... -0.166846 -1.083230 -0.230282
# 2 -0.009725 -0.250268   -0.449773  ... -0.168088 -1.139865 -0.256014
# 3 -0.016349 -0.274578   -0.531003  ... -0.173221 -1.064352 -0.263276
# 4 -0.140037 -0.948183   -1.221457  ... -0.172471 -0.932204 -0.245956
#
#     타인자본회전률   유동자산회전률   당좌자산회전률   재고자산회전률   매출채권회전률  순운전자본회전률  부실기업
# 0 -0.422910 -0.670420 -0.685081 -0.035909 -0.020210 -0.575575     0
# 1 -0.933345 -1.275654 -1.194169 -0.035989 -0.020429 -1.311001     0
# 2 -0.777379 -1.308817 -1.220143 -0.036025 -0.020349 -1.311001     0
# 3 -0.025904 -1.143000 -1.074689 -0.036094 -0.020425 -1.077002     0
# 4 -0.011726 -0.885983 -0.856509 -0.036044 -0.020338 -0.759431     0
#
# [5 rows x 50 columns]

# %%
from scipy.stats import levene

homosced = []
heterosced = []

lev_df = scaled_df_part7.iloc[:, :-1]

nc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==0]  # normal company 
bc_df = scaled_df_part7[scaled_df_part7['부실기업'] ==1]  # bankrupt company

lev_sced_df = pd.DataFrame(index=['등분산성'])

for i in lev_df.columns:
    lev_sced_df[i] = ''
    
    ser_1 = nc_df[i]
    ser_2 = bc_df[i]

    lresult = np.round(levene(ser_1, ser_2)[1], 3)
    
    if lresult < 0.05:
        homosced.append(i)
        lev_sced_df.loc['등분산성', i] = '등분산'
        print(i,"pvalue", lresult,"-> 등분산")
    else:
        heterosced.append(i)
        lev_sced_df.loc['등분산성', i] = '이분산'
        print(i,"pvalue", lresult,"-> 이분산")

    print("**********************************************************")
# Out:
# 총자본증가율 pvalue 0.005 -> 등분산
# **********************************************************
# 순이익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액증가율 pvalue 0.496 -> 이분산
# **********************************************************
# 종업원수증가율 pvalue 0.006 -> 등분산
# **********************************************************
# 정상영업손익증가율 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 매출액순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 총자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본정상영업이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본순이익률 pvalue 0.0 -> 등분산
# **********************************************************
# 금융비용부담률 pvalue 0.0 -> 등분산
# **********************************************************
# 수지비율 pvalue 0.0 -> 등분산
# **********************************************************
# 사내유보 대 자기자본비율 pvalue 0.002 -> 등분산
# **********************************************************
# 1주당매출액 pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순이익 pvalue 0.011 -> 등분산
# **********************************************************
# 1주당 CASH FLOW pvalue 0.0 -> 등분산
# **********************************************************
# 1주당순자산 pvalue 0.0 -> 등분산
# **********************************************************
# 유보율 pvalue 0.0 -> 등분산
# **********************************************************
# 자기자본구성비율 pvalue 0.0 -> 등분산
# **********************************************************
# 유동비율 pvalue 0.815 -> 이분산
# **********************************************************
# 당좌비율 pvalue 0.566 -> 이분산
# **********************************************************
# 현금비율 pvalue 0.777 -> 이분산
# **********************************************************
# 매출채권 대 매입채무비율 pvalue 0.626 -> 이분산
# **********************************************************
# 부채비율 pvalue 0.0 -> 등분산
# **********************************************************
# 이자보상배율 pvalue 0.823 -> 이분산
# **********************************************************
# CASH FLOW 대 부채비율 pvalue 0.021 -> 등분산
# **********************************************************
# CASH FLOW 대 차입금비율 pvalue 0.494 -> 이분산
# **********************************************************
# CASH FLOW 대 총자본비율 pvalue 0.0 -> 등분산
# **********************************************************
# CASH FLOW 대 매출액비율 pvalue 0.0 -> 등분산
# **********************************************************
# 재고자산대순운전자본비율 pvalue 0.303 -> 이분산
# **********************************************************
# 총자본투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 설비투자효율 pvalue 0.0 -> 등분산
# **********************************************************
# 기계투자효율 pvalue 0.545 -> 이분산
# **********************************************************
# 부가가치율 pvalue 0.0 -> 등분산
# **********************************************************
# 노동소득분배율 pvalue 0.0 -> 등분산
# **********************************************************
# 종업원1인당부가가치율_계산 pvalue 0.658 -> 이분산
# **********************************************************
# 노동장비율_계산 pvalue 0.763 -> 이분산
# **********************************************************
# 기계장비율_계산 pvalue 0.525 -> 이분산
# **********************************************************
# 자본집약도_계산 pvalue 0.112 -> 이분산
# **********************************************************
# 총자본회전률 pvalue 0.004 -> 등분산
# **********************************************************
# 자기자본회전률 pvalue 0.612 -> 이분산
# **********************************************************
# 타인자본회전률 pvalue 0.0 -> 등분산
# **********************************************************
# 유동자산회전률 pvalue 0.012 -> 등분산
# **********************************************************
# 당좌자산회전률 pvalue 0.092 -> 이분산
# **********************************************************
# 재고자산회전률 pvalue 0.009 -> 등분산
# **********************************************************
# 매출채권회전률 pvalue 0.653 -> 이분산
# **********************************************************
# 순운전자본회전률 pvalue 0.004 -> 등분산
# **********************************************************

# %%
# 피처별 등분산성 데이터프레임 생성
lev_sced_df = lev_sced_df.transpose()
lev_sced_df
# Out:
#                   등분산성
# 총자본증가율             등분산
# 순이익증가율             등분산
# 자기자본증가율            등분산
# 매출액증가율             이분산
# 종업원수증가율            등분산
# 정상영업손익증가율          등분산
# 매출액정상영업이익률         등분산
# 매출액순이익률            등분산
# 총자본순이익률            등분산
# 총자본정상영업이익률         등분산
# 자기자본정상영업이익률        등분산
# 자기자본순이익률           등분산
# 금융비용부담률            등분산
# 수지비율               등분산
# 사내유보 대 자기자본비율      등분산
# 1주당매출액             등분산
# 1주당순이익             등분산
# 1주당 CASH FLOW      등분산
# 1주당순자산             등분산
# 유보율                등분산
# 자기자본구성비율           등분산
# 유동비율               이분산
# 당좌비율               이분산
# 현금비율               이분산
# 매출채권 대 매입채무비율      이분산
# 부채비율               등분산
# 이자보상배율             이분산
# CASH FLOW 대 부채비율   등분산
# CASH FLOW 대 차입금비율  이분산
# CASH FLOW 대 총자본비율  등분산
# CASH FLOW 대 매출액비율  등분산
# 재고자산대순운전자본비율       이분산
# 총자본투자효율            등분산
# 설비투자효율             등분산
# 기계투자효율             이분산
# 부가가치율              등분산
# 노동소득분배율            등분산
# 종업원1인당부가가치율_계산     이분산
# 노동장비율_계산           이분산
# 기계장비율_계산           이분산
# 자본집약도_계산           이분산
# 총자본회전률             등분산
# 자기자본회전률            이분산
# 타인자본회전률            등분산
# 유동자산회전률            등분산
# 당좌자산회전률            이분산
# 재고자산회전률            등분산
# 매출채권회전률            이분산
# 순운전자본회전률           등분산

# %%
lev_sced_df.value_counts()
# Out:
# 등분산성
# 등분산     33
# 이분산     16
# dtype: int64

# %% [markdown]
# ### RobustScaler Welch's ttest_ind

# %%
import numpy as np
from scipy.stats import ttest_ind

welch_df = scaled_df_part7.iloc[:, :-1]

nc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_homosced_df = scaled_df_part7.loc[:, homosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_homosced = []       # 유의수준 피처

# 등분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_homosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=True)
        
        if welch_result.pvalue < 0.05:
            significant_homosced.append(i)
            
        print("등분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_homo(nc_homosced_df, bc_homosced_df)
# Out:
# 등분산을 가정한 총자본증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 순이익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본증가율 의 pvalue: 0.006
# **********************************************************
# 등분산을 가정한 종업원수증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 정상영업손익증가율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 매출액순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본정상영업이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본순이익률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 금융비용부담률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 수지비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 사내유보 대 자기자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당매출액 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순이익 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당 CASH FLOW 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 1주당순자산 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유보율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 자기자본구성비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 부채비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 총자본비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 CASH FLOW 대 매출액비율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 총자본투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 설비투자효율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 부가가치율 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 노동소득분배율 의 pvalue: 0.036
# **********************************************************
# 등분산을 가정한 총자본회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 타인자본회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 유동자산회전률 의 pvalue: 0.0
# **********************************************************
# 등분산을 가정한 재고자산회전률 의 pvalue: 0.009
# **********************************************************
# 등분산을 가정한 순운전자본회전률 의 pvalue: 0.0
# **********************************************************

# %%
# 유의수준 피처
print('유의수준 피처 개수: ', len(significant_homosced), '개')
print(significant_homosced)
# Out:
# 유의수준 피처 개수:  33 개
# ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']

# %%
import numpy as np
from scipy.stats import ttest_ind

# welch_df = scaled_df_part7.iloc[:, :-1]

nc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==0]  # normal company 
bc_heterosced_df = scaled_df_part7.loc[:, heterosced][scaled_df_part7['부실기업'] ==1]  # bankrupt company

significant_heterosced = []     # 유의수준 피처

# 이분산성 Welch's T-test
def ttest_homo(df_name1, df_name2):
    for i in nc_heterosced_df.columns:
        welch_result = ttest_ind(df_name1[i], df_name2[i], equal_var=False)
        
        if welch_result.pvalue < 0.05:
            significant_heterosced.append(i)
            
        print("이분산을 가정한", i, "의 pvalue:", np.round(welch_result.pvalue, 3))
    
        print("**********************************************************")

# %%
ttest_hetero(nc_heterosced_df, bc_heterosced_df)
# Out:
# 이분산을 가정한 매출액증가율 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 유동비율 의 pvalue: 0.14
# **********************************************************
# 이분산을 가정한 당좌비율 의 pvalue: 0.44
# **********************************************************
# 이분산을 가정한 현금비율 의 pvalue: 0.539
# **********************************************************
# 이분산을 가정한 매출채권 대 매입채무비율 의 pvalue: 0.059
# **********************************************************
# 이분산을 가정한 이자보상배율 의 pvalue: 0.017
# **********************************************************
# 이분산을 가정한 CASH FLOW 대 차입금비율 의 pvalue: 0.65
# **********************************************************
# 이분산을 가정한 재고자산대순운전자본비율 의 pvalue: 0.567
# **********************************************************
# 이분산을 가정한 기계투자효율 의 pvalue: 0.055
# **********************************************************
# 이분산을 가정한 종업원1인당부가가치율_계산 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 노동장비율_계산 의 pvalue: 0.643
# **********************************************************
# 이분산을 가정한 기계장비율_계산 의 pvalue: 0.303
# **********************************************************
# 이분산을 가정한 자본집약도_계산 의 pvalue: 0.038
# **********************************************************
# 이분산을 가정한 자기자본회전률 의 pvalue: 0.538
# **********************************************************
# 이분산을 가정한 당좌자산회전률 의 pvalue: 0.0
# **********************************************************
# 이분산을 가정한 매출채권회전률 의 pvalue: 0.072
# **********************************************************

# %%
# 유의한 피처
print('유의수준 피처 개수: ', len(significant_heterosced), '개')
print(significant_heterosced)
# Out:
# 유의수준 피처 개수:  5 개
# ['매출액증가율', '이자보상배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '당좌자산회전률']

# %%
print('등분산 유의수준 피처: ', significant_homosced)
print('-------------------------------------------------------------------')
print('이분산 유의수준 피처: ', significant_heterosced)
# Out:
# 등분산 유의수준 피처:  ['총자본증가율', '순이익증가율', '자기자본증가율', '종업원수증가율', '정상영업손익증가율', '매출액정상영업이익률', '매출액순이익률', '총자본순이익률', '총자본정상영업이익률', '자기자본정상영업이익률', '자기자본순이익률', '금융비용부담률', '수지비율', '사내유보 대 자기자본비율', '1주당매출액', '1주당순이익', '1주당 CASH FLOW', '1주당순자산', '유보율', '자기자본구성비율', '부채비율', 'CASH FLOW 대 부채비율', 'CASH FLOW 대 총자본비율', 'CASH FLOW 대 매출액비율', '총자본투자효율', '설비투자효율', '부가가치율', '노동소득분배율', '총자본회전률', '타인자본회전률', '유동자산회전률', '재고자산회전률', '순운전자본회전률']
# -------------------------------------------------------------------
# 이분산 유의수준 피처:  ['매출액증가율', '이자보상배율', '종업원1인당부가가치율_계산', '자본집약도_계산', '당좌자산회전률']
