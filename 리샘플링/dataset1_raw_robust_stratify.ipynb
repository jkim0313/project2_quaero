# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/선택된피처/dataset1_general_raw+robust.csv', encoding='CP949')
df.drop(columns='Unnamed: 0', inplace=True)
df
# Out:
#             회사명  거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업        업종  \
# 0      (주)CMG제약  58820  201112  200108      NaN      0      0     0       제조업
# 1      (주)CMG제약  58820  201212  200108      NaN      0      0     0       제조업
# 2      (주)CMG제약  58820  201312  200108      NaN      0      0     0       제조업
# 3      (주)CMG제약  58820  201412  200108      NaN      0      0     0       제조업
# 4      (주)CMG제약  58820  201512  200108      NaN      0      0     0       제조업
# ...         ...    ...     ...     ...      ...    ...    ...   ...       ...
# 12738   흥아해운(주)   3280  201312  197606      NaN      0      0     0  운수 및 창고업
# 12739   흥아해운(주)   3280  201412  197606      NaN      0      0     0  운수 및 창고업
# 12740   흥아해운(주)   3280  201512  197606      NaN      0      0     0  운수 및 창고업
# 12741   흥아해운(주)   3280  201612  197606      NaN      0      0     0  운수 및 창고업
# 12742   흥아해운(주)   3280  201712  197606      NaN      1      0     1  운수 및 창고업
#
# ...

# %%
df['부실기업'].value_counts()
# Out:
# 0    11986
# 1      757
# Name: 부실기업, dtype: int64

# %%
df_700 = df.groupby('부실기업', group_keys=False).apply(lambda x: x.sample(700)).drop_duplicates(['회사명'])
df_700['회사명'].value_counts()
# Out:
# 진원생명과학(주)     1
# (주)파인테크닉스     1
# 쌍용정보통신(주)     1
# (주)이수페타시스     1
# (주)씨에스        1
#              ..
# (주)에스피씨삼립     1
# 엘지디스플레이(주)    1
# (주)네오위즈       1
# (주)유성티엔에스     1
# (주)손오공        1
# Name: 회사명, Length: 1182, dtype: int64

# %%
df_700['부실기업'].value_counts()
# Out:
# 1    599
# 0    583
# Name: 부실기업, dtype: int64

# %%
df_700
# Out:
#                회사명   거래소코드    회계년도     상장일  상장폐지일_x  부실기업1  부실기업2  부실기업  \
# 11338    진원생명과학(주)   11000  201912  198711      NaN      0      0     0
# 10062  알에스오토메이션(주)  140670  201712  201708      NaN      0      0     0
# 722        (주)대림제지   17650  201612  199411      NaN      0      0     0
# 11795    포스코홀딩스(주)    5490  201712  198806      NaN      0      0     0
# 5262   (주)일신바이오베이스   68330  202012  200712      NaN      0      0     0
# ...            ...     ...     ...     ...      ...    ...    ...   ...
# 4898      (주)이건홀딩스   39020  201112  200005      NaN      1      0     1
# 574        (주)누리플랜   69140  201312  201010      NaN      1      0     1
# 2359        (주)선앤엘    2820  201812  197605      NaN      1      0     1
# 813          (주)대창   12800  201312  198912      NaN      1      0     1
# 2563        (주)손오공   66910  201312  200501      NaN      1      0     1
#
#              업종  경기민감도     총자본증가율  종업원수증가율  매출액정상영업이익률  총자본정상영업이익률  \
# ...
